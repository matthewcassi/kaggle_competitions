# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv('test.csv')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# MSZoning         1455 non-null object
# LotFrontage      1232 non-null float64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# LandContour      1459 non-null object
# Utilities        1457 non-null object
# LotConfig        1459 non-null object
# LandSlope        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# HouseStyle       1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# ...

# %%
test.drop(['PoolQC','Fence','MiscFeature','Alley'], inplace=True, axis=1)

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# FireplaceQu      730
# LotFrontage      227
# GarageCond        78
# GarageQual        78
# GarageYrBlt       78
# GarageFinish      78
# GarageType        76
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# MasVnrType        16
# MasVnrArea        15
# MSZoning           4
# BsmtHalfBath       2
# Utilities          2
# Functional         2
# BsmtFullBath       2
# BsmtUnfSF          1
# SaleType           1
# BsmtFinSF2         1
# BsmtFinSF1         1
# Exterior2nd        1
# Exterior1st        1
# TotalBsmtSF        1
# GarageCars         1
# KitchenQual        1
# GarageArea         1
# HouseStyle         0
#                 ...
# BldgType           0
# Condition2         0
# SaleCondition      0
# ExterCond          0
# TotRmsAbvGrd       0
# YrSold             0
# MoSold             0
# MiscVal            0
# PoolArea           0
# ScreenPorch        0
# 3SsnPorch          0
# EnclosedPorch      0
# ...

# %%
test[test['FireplaceQu'].isnull()][['Fireplaces','FireplaceQu']]
# Out:
#       Fireplaces FireplaceQu
# 0              0         NaN
# 1              0         NaN
# 4              0         NaN
# 6              0         NaN
# 9              0         NaN
# 11             0         NaN
# 12             0         NaN
# 14             0         NaN
# 16             0         NaN
# 22             0         NaN
# 23             0         NaN
# 28             0         NaN
# 30             0         NaN
# 31             0         NaN
# 36             0         NaN
# 37             0         NaN
# 38             0         NaN
# 39             0         NaN
# 40             0         NaN
# 41             0         NaN
# 45             0         NaN
# 48             0         NaN
# 49             0         NaN
# 50             0         NaN
# 51             0         NaN
# 52             0         NaN
# 53             0         NaN
# 57             0         NaN
# 58             0         NaN
# 59             0         NaN
# ...          ...         ...
# ...

# %%
test['FireplaceQu'] = test['FireplaceQu'].fillna('None')

# %%
test[test['GarageType'].isnull()][['GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual',
                                    'GarageCond']]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 53          NaN          NaN          NaN         0.0         0.0        NaN
# 71          NaN          NaN          NaN         0.0         0.0        NaN
# 79          NaN          NaN          NaN         0.0         0.0        NaN
# 92          NaN          NaN          NaN         0.0         0.0        NaN
# 96          NaN          NaN          NaN         0.0         0.0        NaN
# 98          NaN          NaN          NaN         0.0         0.0        NaN
# 100         NaN          NaN          NaN         0.0         0.0        NaN
# 130         NaN          NaN          NaN         0.0         0.0        NaN
# 133         NaN          NaN          NaN         0.0         0.0        NaN
# 134         NaN          NaN          NaN         0.0         0.0        NaN
# 154         NaN          NaN          NaN         0.0         0.0        NaN
# ...

# %%
test['GarageType'] = test['GarageType'].fillna('None')
test['GarageYrBlt'] = test['GarageYrBlt'].fillna('None')
test['GarageQual'] = test['GarageQual'].fillna('None')
test['GarageCond'] = test['GarageCond'].fillna('None')
test['GarageFinish'] = test['GarageFinish'].fillna('None')

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# LotFrontage      227
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType2      42
# BsmtFinType1      42
# MasVnrType        16
# MasVnrArea        15
# MSZoning           4
# Utilities          2
# Functional         2
# BsmtFullBath       2
# BsmtHalfBath       2
# BsmtFinSF2         1
# BsmtUnfSF          1
# SaleType           1
# BsmtFinSF1         1
# Exterior2nd        1
# Exterior1st        1
# KitchenQual        1
# TotalBsmtSF        1
# GarageCars         1
# GarageArea         1
# OverallCond        0
# ExterCond          0
# MSSubClass         0
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
#                 ...
# GarageYrBlt        0
# YrSold             0
# MoSold             0
# MiscVal            0
# PoolArea           0
# ScreenPorch        0
# 3SsnPorch          0
# EnclosedPorch      0
# OpenPorchSF        0
# WoodDeckSF         0
# PavedDrive         0
# GarageCond         0
# ...

# %%
test[test['BsmtQual'].isnull()][['BsmtQual','BsmtCond','BsmtFinType1','BsmtFinType2','BsmtExposure','TotalBsmtSF']]
# Out:
#      BsmtQual BsmtCond BsmtFinType1 BsmtFinType2 BsmtExposure  TotalBsmtSF
# 125       NaN      NaN          NaN          NaN          NaN          0.0
# 133       NaN      NaN          NaN          NaN          NaN          0.0
# 269       NaN      NaN          NaN          NaN          NaN          0.0
# 318       NaN      NaN          NaN          NaN          NaN          0.0
# 354       NaN      NaN          NaN          NaN          NaN          0.0
# 387       NaN      NaN          NaN          NaN          NaN          0.0
# 388       NaN      NaN          NaN          NaN          NaN          0.0
# 396       NaN      NaN          NaN          NaN          NaN          0.0
# 397       NaN      NaN          NaN          NaN          NaN          0.0
# 398       NaN      NaN          NaN          NaN          NaN          0.0
# 400       NaN      NaN          NaN          NaN          NaN          0.0
# ...

# %%
test['BsmtQual'] = test['BsmtQual'].fillna('None')
test['BsmtCond'] = test['BsmtCond'].fillna('None')
test['BsmtFinType1'] = test['BsmtFinType1'].fillna('None')
test['BsmtFinType2'] = test['BsmtFinType2'].fillna('None')
test['BsmtExposure'] = test['BsmtExposure'].fillna('None')

# %%
test['LotFrontage'] = test['LotFrontage'].fillna(test['LotFrontage'].median())

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# MasVnrType       16
# MasVnrArea       15
# MSZoning          4
# Functional        2
# Utilities         2
# BsmtFullBath      2
# BsmtHalfBath      2
# GarageCars        1
# BsmtFinSF2        1
# BsmtUnfSF         1
# SaleType          1
# Exterior2nd       1
# Exterior1st       1
# KitchenQual       1
# TotalBsmtSF       1
# GarageArea        1
# BsmtFinSF1        1
# BldgType          0
# HouseStyle        0
# BsmtExposure      0
# MSSubClass        0
# LotFrontage       0
# LotArea           0
# BsmtCond          0
# BsmtQual          0
# Foundation        0
# ExterCond         0
# ExterQual         0
# Street            0
# LotShape          0
#                  ..
# YrSold            0
# MoSold            0
# MiscVal           0
# PoolArea          0
# ScreenPorch       0
# 3SsnPorch         0
# EnclosedPorch     0
# OpenPorchSF       0
# WoodDeckSF        0
# PavedDrive        0
# GarageCond        0
# GarageQual        0
# GarageFinish      0
# GarageYrBlt       0
# ...

# %%
test[test['MasVnrType'].isnull()][['MasVnrType','MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 231         NaN         NaN
# 246         NaN         NaN
# 422         NaN         NaN
# 532         NaN         NaN
# 544         NaN         NaN
# 581         NaN         NaN
# 851         NaN         NaN
# 865         NaN         NaN
# 880         NaN         NaN
# 889         NaN         NaN
# 908         NaN         NaN
# 1132        NaN         NaN
# 1150        NaN       198.0
# 1197        NaN         NaN
# 1226        NaN         NaN
# 1402        NaN         NaN

# %%
sns.boxplot(x='MasVnrType',y='MasVnrArea',data=test)

# %%
test['MasVnrType'].value_counts()
# Out:
# None       878
# BrkFace    434
# Stone      121
# BrkCmn      10
# Name: MasVnrType, dtype: int64

# %%
test[test['MasVnrType'] == 'BrkFace']['MasVnrArea'].describe()
# Out:
# count     434.000000
# mean      264.403226
# std       205.507205
# min         0.000000
# 25%       128.000000
# 50%       203.000000
# 75%       354.500000
# max      1290.000000
# Name: MasVnrArea, dtype: float64

# %%
test[test['MasVnrType'] == 'Stone']['MasVnrArea'].describe()
# Out:
# count     121.000000
# mean      239.809917
# std       188.868178
# min        16.000000
# 25%       122.000000
# 50%       198.000000
# 75%       300.000000
# max      1224.000000
# Name: MasVnrArea, dtype: float64

# %%
test[(test['MasVnrType'].isnull()) & (test['MasVnrArea'] == 198.0)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1150  2611          20       RL        124.0    27697   Pave      Reg
#
#      LandContour Utilities LotConfig      ...       OpenPorchSF EnclosedPorch  \
# 1150         Lvl    AllPub    Inside      ...                38             0
#
#      3SsnPorch ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  \
# 1150         0           0        0       0      11    2007       COD
#
#       SaleCondition
# 1150        Abnorml
#
# [1 rows x 76 columns]

# %%
test.loc[1150,'MasVnrType'] = 'BrkFace'

# %%
test[test['MasVnrType'].isnull()][['MasVnrType','MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 231         NaN         NaN
# 246         NaN         NaN
# 422         NaN         NaN
# 532         NaN         NaN
# 544         NaN         NaN
# 581         NaN         NaN
# 851         NaN         NaN
# 865         NaN         NaN
# 880         NaN         NaN
# 889         NaN         NaN
# 908         NaN         NaN
# 1132        NaN         NaN
# 1197        NaN         NaN
# 1226        NaN         NaN
# 1402        NaN         NaN

# %%
test['MasVnrType'] = test['MasVnrType'].fillna('None')
test['MasVnrArea'] = test['MasVnrArea'].fillna(0)

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# MSZoning         4
# Functional       2
# BsmtFullBath     2
# BsmtHalfBath     2
# Utilities        2
# GarageArea       1
# BsmtFinSF2       1
# BsmtUnfSF        1
# SaleType         1
# Exterior2nd      1
# Exterior1st      1
# KitchenQual      1
# GarageCars       1
# TotalBsmtSF      1
# BsmtFinSF1       1
# LotShape         0
# BsmtExposure     0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# BsmtCond         0
# BsmtQual         0
# Foundation       0
# ExterCond        0
# ExterQual        0
# MasVnrArea       0
# MasVnrType       0
# Street           0
# Condition1       0
# Neighborhood     0
#                 ..
# YrSold           0
# MoSold           0
# MiscVal          0
# PoolArea         0
# ScreenPorch      0
# 3SsnPorch        0
# EnclosedPorch    0
# OpenPorchSF      0
# WoodDeckSF       0
# PavedDrive       0
# GarageCond       0
# GarageQual       0
# GarageFinish     0
# GarageYrBlt      0
# GarageType       0
# FireplaceQu      0
# ...

# %%
test[test['BsmtFinSF2'].isnull()][['BsmtQual','BsmtCond','BsmtFinType1','BsmtFinType2','BsmtExposure','TotalBsmtSF', \
                                   'BsmtUnfSF','BsmtFinSF1','BsmtFinSF2']]
# Out:
#     BsmtQual BsmtCond BsmtFinType1 BsmtFinType2 BsmtExposure  TotalBsmtSF  \
# 660     None     None         None         None         None          NaN
#
#      BsmtUnfSF  BsmtFinSF1  BsmtFinSF2
# 660        NaN         NaN         NaN

# %%
test['TotalBsmtSF'] = test['TotalBsmtSF'].fillna(0)
test['BsmtUnfSF'] = test['BsmtUnfSF'].fillna(0)
test['BsmtFinSF1'] = test['BsmtFinSF1'].fillna(0)
test['BsmtFinSF2'] = test['BsmtFinSF2'].fillna(0)

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# MSZoning         4
# Functional       2
# BsmtHalfBath     2
# Utilities        2
# BsmtFullBath     2
# GarageArea       1
# SaleType         1
# Exterior1st      1
# KitchenQual      1
# GarageCars       1
# Exterior2nd      1
# SaleCondition    0
# RoofStyle        0
# RoofMatl         0
# MasVnrArea       0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# YearRemodAdd     0
# OverallCond      0
# YearBuilt        0
# LotConfig        0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# EnclosedPorch    0
# BsmtFinSF2       0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# GarageType       0
# FireplaceQu      0
# Fireplaces       0
# TotRmsAbvGrd     0
# ...

# %%
test['Functional'].value_counts()
# Out:
# Typ     1357
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64

# %%
test['Functional'] = test['Functional'].fillna('Typ')

# %%
test['Functional'].value_counts()
# Out:
# Typ     1359
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64

# %%
test[test['BsmtHalfBath'].isnull()][['BsmtQual','BsmtCond','BsmtFinType1','BsmtFinType2','BsmtExposure','TotalBsmtSF', \
                                   'BsmtUnfSF','BsmtFinSF1','BsmtFinSF2']]
# Out:
#     BsmtQual BsmtCond BsmtFinType1 BsmtFinType2 BsmtExposure  TotalBsmtSF  \
# 660     None     None         None         None         None          0.0
# 728     None     None         None         None         None          0.0
#
#      BsmtUnfSF  BsmtFinSF1  BsmtFinSF2
# 660        0.0         0.0         0.0
# 728        0.0         0.0         0.0

# %%
test[test['BsmtFullBath'].isnull()][['BsmtQual','BsmtCond','BsmtFinType1','BsmtFinType2','BsmtExposure','TotalBsmtSF', \
                                   'BsmtUnfSF','BsmtFinSF1','BsmtFinSF2']]
# Out:
#     BsmtQual BsmtCond BsmtFinType1 BsmtFinType2 BsmtExposure  TotalBsmtSF  \
# 660     None     None         None         None         None          0.0
# 728     None     None         None         None         None          0.0
#
#      BsmtUnfSF  BsmtFinSF1  BsmtFinSF2
# 660        0.0         0.0         0.0
# 728        0.0         0.0         0.0

# %%
test['BsmtFullBath'] = test['BsmtFullBath'].fillna(0)
test['BsmtHalfBath'] = test['BsmtHalfBath'].fillna(0)

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# MSZoning         4
# Utilities        2
# KitchenQual      1
# SaleType         1
# Exterior1st      1
# Exterior2nd      1
# GarageCars       1
# GarageArea       1
# MasVnrArea       0
# RoofStyle        0
# RoofMatl         0
# MasVnrType       0
# SaleCondition    0
# ExterQual        0
# YearRemodAdd     0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# ExterCond        0
# OverallCond      0
# YearBuilt        0
# LotConfig        0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
#                 ..
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# EnclosedPorch    0
# FireplaceQu      0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# GarageType       0
# Fireplaces       0
# Heating          0
# GrLivArea        0
# HeatingQC        0
# ...

# %%
test[test['GarageCars'].isnull()][['GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual',
                                    'GarageCond']]
# Out:
#      GarageType GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 1116     Detchd        None         None         NaN         NaN       None
#
#      GarageCond
# 1116       None

# %%
test[test['GarageArea'].isnull()][['GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual',
                                    'GarageCond']]
# Out:
#      GarageType GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 1116     Detchd        None         None         NaN         NaN       None
#
#      GarageCond
# 1116       None

# %%
test[test['GarageType'] == 'Detchd']['GarageCars'].median()
# Out:
# 1.0

# %%
test[test['GarageType'] == 'Detchd']['GarageArea'].median()
# Out:
# 384.0

# %%
test['GarageCars'] = test['GarageCars'].fillna(1.0)
test['GarageArea'] = test['GarageArea'].fillna(384.0)

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# MSZoning         4
# Utilities        2
# SaleType         1
# KitchenQual      1
# Exterior1st      1
# Exterior2nd      1
# Foundation       0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# BsmtQual         0
# RoofStyle        0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# RoofMatl         0
# SaleCondition    0
# YearRemodAdd     0
# BsmtUnfSF        0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# LotConfig        0
#                 ..
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# GarageYrBlt      0
# GarageType       0
# FireplaceQu      0
# BsmtFullBath     0
# CentralAir       0
# ...

# %%
test[test['Exterior1st'].isnull()][['YearBuilt','YearRemodAdd','Exterior1st','Exterior2nd']]
# Out:
#      YearBuilt  YearRemodAdd Exterior1st Exterior2nd
# 691       1940          2007         NaN         NaN

# %%
test[test['YearBuilt'] < 1950]['Exterior1st'].value_counts()
# Out:
# Wd Sdng    117
# MetalSd     87
# VinylSd     41
# AsbShng     18
# Stucco      17
# WdShing     11
# BrkFace      8
# Plywood      6
# HdBoard      4
# BrkComm      2
# AsphShn      1
# CemntBd      1
# Name: Exterior1st, dtype: int64

# %%
test[test['YearBuilt'] < 1950]['Exterior2nd'].value_counts()
# Out:
# Wd Sdng    106
# MetalSd     83
# VinylSd     42
# Stucco      19
# Wd Shng     19
# AsbShng     15
# Plywood     14
# HdBoard      7
# BrkFace      3
# CmentBd      2
# Brk Cmn      1
# CBlock       1
# AsphShn      1
# Name: Exterior2nd, dtype: int64

# %%
test['Exterior1st'] = test['Exterior1st'].fillna('Wd Sdng')
test['Exterior2nd'] = test['Exterior2nd'].fillna('Wd Sdng')

# %%
test[test['KitchenQual'].isnull()][['KitchenQual','SaleCondition','KitchenAbvGr','OverallQual']]
# Out:
#    KitchenQual SaleCondition  KitchenAbvGr  OverallQual
# 95         NaN        Normal             1            5

# %%
test[test['OverallQual']==5]['KitchenQual'].value_counts()
# Out:
# TA    342
# Gd     66
# Fa     12
# Ex      7
# Name: KitchenQual, dtype: int64

# %%
test['KitchenQual'] = test['KitchenQual'].fillna('TA')

# %%
test[test['SaleType'].isnull()][['YearBuilt','YearRemodAdd']]
# Out:
#       YearBuilt  YearRemodAdd
# 1029       1958          1998

# %%
test[test['YearRemodAdd'] < 2000]['SaleType'].value_counts()
# Out:
# WD       859
# COD       42
# ConLD     12
# CWD        6
# ConLI      3
# Oth        3
# ConLw      3
# Con        2
# Name: SaleType, dtype: int64

# %%
test['SaleType'] = test['SaleType'].fillna('WD')

# %%
test['Utilities'].value_counts()
# Out:
# AllPub    1457
# Name: Utilities, dtype: int64

# %%
test[test['Utilities'].isnull()]['YearBuilt'].value_counts()
# Out:
# 1910    1
# 1952    1
# Name: YearBuilt, dtype: int64

# %%
test[test['YearBuilt'] < 1955]['Utilities'].value_counts()
# Out:
# AllPub    386
# Name: Utilities, dtype: int64

# %%
test['Utilities'] = test['Utilities'].fillna('AllPub')

# %%
test[test['MSZoning'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 455   1916          30      NaN        109.0    21780   Grvl      Reg
# 756   2217          20      NaN         80.0    14584   Pave      Reg
# 790   2251          70      NaN         67.0    56600   Pave      IR1
# 1444  2905          20      NaN        125.0    31250   Pave      Reg
#
#      LandContour Utilities LotConfig      ...       OpenPorchSF EnclosedPorch  \
# 455          Lvl    AllPub    Inside      ...                24             0
# 756          Low    AllPub    Inside      ...                 0             0
# 790          Low    AllPub    Inside      ...                 0             0
# 1444         Lvl    AllPub    Inside      ...                 0           135
#
#      3SsnPorch ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  \
# 455          0           0        0       0       3    2009     ConLD
# 756          0           0        0       0       2    2008        WD
# ...

# %%
test[test['MSZoning'].isnull()]['Neighborhood']
# Out:
# 455      IDOTRR
# 756      IDOTRR
# 790      IDOTRR
# 1444    Mitchel
# Name: Neighborhood, dtype: object

# %%
test[test['Neighborhood'] == 'IDOTRR']['MSZoning'].value_counts()
# Out:
# RM         40
# C (all)    13
# Name: MSZoning, dtype: int64

# %%
test[test['Neighborhood'] == 'Mitchel']['MSZoning'].value_counts()
# Out:
# RL    60
# RM     4
# Name: MSZoning, dtype: int64

# %%
test.loc[455,'MSZoning'] = 'RM'
test.loc[756,'MSZoning'] = 'RM'
test.loc[790,'MSZoning'] = 'RM'
test.loc[1444,'MSZoning'] = 'RL'

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# SaleCondition    0
# ExterCond        0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# Foundation       0
# SaleType         0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# YearRemodAdd     0
# YearBuilt        0
# OverallCond      0
# OverallQual      0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
#                 ..
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# GarageYrBlt      0
# FireplaceQu      0
# HeatingQC        0
# Fireplaces       0
# CentralAir       0
# Electrical       0
# ...

# %%
test['bathrooms'] = test['HalfBath']* 0.5 + test['FullBath'] \
                    + test['BsmtFullBath'] + test['BsmtHalfBath'] * 0.5

# %%
test['total_sq_ft'] = test['BsmtFinSF1'] + test['BsmtFinSF2'] + test['1stFlrSF'] + test['2ndFlrSF']

# %%
test['total_sq_ft_plus_unf'] = test['BsmtFinSF1'] + test['BsmtFinSF2'] + test['1stFlrSF'] + test['2ndFlrSF'] \
                                + test['BsmtUnfSF']

# %%
def remod(row):
    remod = 0
    if row['YearRemodAdd'] > row['YearBuilt']:
        remod = 1
    return remod

# %%
test['remodel'] = test.apply(remod, axis=1)

# %%
test['total_porch_sf'] = test['WoodDeckSF'] + test['OpenPorchSF'] + test['EnclosedPorch'] + test['3SsnPorch'] + \
                          test['ScreenPorch']

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 81 columns):
# Id                      1459 non-null int64
# MSSubClass              1459 non-null int64
# MSZoning                1459 non-null object
# LotFrontage             1459 non-null float64
# LotArea                 1459 non-null int64
# Street                  1459 non-null object
# LotShape                1459 non-null object
# LandContour             1459 non-null object
# Utilities               1459 non-null object
# LotConfig               1459 non-null object
# LandSlope               1459 non-null object
# Neighborhood            1459 non-null object
# Condition1              1459 non-null object
# Condition2              1459 non-null object
# BldgType                1459 non-null object
# HouseStyle              1459 non-null object
# OverallQual             1459 non-null int64
# OverallCond             1459 non-null int64
# ...

# %%
test.to_csv('updated_test.csv', index=False)
