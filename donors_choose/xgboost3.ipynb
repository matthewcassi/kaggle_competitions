# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils.class_weight import compute_sample_weight

# %%
donors_choose = pd.read_csv('train_clean3.csv')

# %%
donors_choose.head()
# Out:
#    Unnamed: 0       id                        teacher_id teacher_prefix  \
# 0           0  p036502  484aaf11257089a66cfedc9461c6bd0a            Ms.
# 1           1  p039565  df72a3ba8089423fa8a94be88060f6ed           Mrs.
# 2           2  p233823  a9b876a9252e08a55e3d894150f75ba3            Ms.
# 3           3  p185307  525fdbb6ec7f538a48beebaa0a51b24f            Mr.
# 4           4  p013780  a63b5547a7239eae4c1872670848e61a            Mr.
#
#   school_state project_submitted_datetime project_grade_category  \
# 0           NV        2016-11-18 14:45:59          Grades PreK-2
# 1           GA        2017-04-26 15:57:28             Grades 3-5
# 2           UT        2017-01-01 22:57:44             Grades 3-5
# 3           NC        2016-08-12 15:42:11             Grades 3-5
# 4           CA        2016-08-06 09:09:11             Grades 6-8
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                            26                    1
# 1                                             1                    0
# 2                                             5                    1
# 3                                            16                    0
# 4                                            42                    1
#
#    Applied Learning   ...    quantity_std  price_count  price_sum  price_min  \
# 0               0.0   ...             0.0            2     299.98     149.99
# 1               0.0   ...             NaN            1      20.00      20.00
# 2               0.0   ...             NaN            1     469.99     469.99
# 3               0.0   ...             0.0            5     684.47      18.95
# 4               0.0   ...             NaN            1     355.50     355.50
#
#    price_max  price_mean   price_std  mean_price  hour  minute
# 0     149.99     149.990    0.000000   49.996667    14      45
# 1      20.00      20.000         NaN    1.000000    15      57
# 2     469.99     469.990         NaN  469.990000    22      57
# 3     354.99     136.894  133.428098  136.894000    15      42
# 4     355.50     355.500         NaN  177.750000     9       9
#
# [5 rows x 74 columns]

# %%
donors_choose.drop('Unnamed: 0', 1, inplace=True)

# %%
donors_choose['teacher_prefix'] = donors_choose['teacher_prefix'].astype('category')
donors_choose['school_state'] = donors_choose['school_state'].astype('category')
donors_choose['project_grade_category'] = donors_choose['project_grade_category'].astype('category')

donors_choose = pd.get_dummies(donors_choose,columns = ['teacher_prefix','school_state','project_grade_category'],drop_first=True)

# %%
count_vec = TfidfVectorizer(max_df=0.99, min_df=0.01, norm='l2')
count_vec_df = count_vec.fit_transform(donors_choose['lemm_text'])
count_vec_df = pd.DataFrame(count_vec_df.todense(), index=donors_choose.index, columns=count_vec.get_feature_names())

# %%
list(donors_choose.columns)
# Out:
# ['id',
#  'teacher_id',
#  'project_submitted_datetime',
#  'teacher_number_of_previously_posted_projects',
#  'project_is_approved',
#  'Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'essay1_count',
#  'essay2_count',
#  'essay3_count',
#  'essay4_count',
#  'project_resource_summary_count',
#  'desc_count',
#  'essay1_count_nostop',
#  'essay2_count_nostop',
#  'essay3_count_nostop',
#  'essay4_count_nostop',
#  'proj_resouce_count_nostop',
#  'desc_count_nostop',
#  'full_text',
#  'lemm_text',
#  'month',
#  'dow',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'quantity_std',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'price_std',
#  'mean_price',
#  'hour',
#  'minute',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2']

# %%
scale_df = donors_choose[['teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price']]

scale_df.isna().any()
# Out:
# teacher_number_of_previously_posted_projects    False
# quantity_sum                                    False
# quantity_min                                    False
# quantity_max                                    False
# quantity_mean                                   False
# price_count                                     False
# price_sum                                       False
# price_min                                       False
# price_max                                       False
# price_mean                                      False
# mean_price                                      False
# dtype: bool

# %%
scaler = MinMaxScaler()
scale_features = scaler.fit_transform(scale_df.values)
scale_df= pd.DataFrame(scale_features, index=scale_df.index, columns=scale_df.columns)

# %%
x = donors_choose.drop(['teacher_id','project_submitted_datetime','project_is_approved','id','full_text','lemm_text','teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price','essay1_count',
 'essay2_count',
 'essay3_count',
 'essay4_count',
 'project_resource_summary_count',
 'desc_count','essay1_count_nostop',
 'essay2_count_nostop',
 'essay3_count_nostop',
 'essay4_count_nostop',
 'proj_resouce_count_nostop',
 'desc_count_nostop','minute','price_std','quantity_std','hour'], 1)
y = donors_choose['project_is_approved']

# %%
list(x.columns)
# Out:
# ['Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'month',
#  'dow',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2']

# %%
pre_x = x.merge(count_vec_df, how='left', left_index=True, right_index=True)
full_x = pre_x.merge(scale_df, how='left', left_index=True, right_index=True)

full_x_array = full_x.as_matrix().astype(np.float)
y = y.as_matrix().astype(np.float)

# %%
x_train, x_test, y_train, y_test = train_test_split(full_x_array, y, test_size = 0.2, random_state=17)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((130422, 1816), (32606, 1816), (130422,), (32606,))

# %%
list(full_x.columns)
# Out:
# ['Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'month_x',
#  'dow',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'aa',
#  'ability',
#  'able',
#  'absolutely',
#  'academic',
#  'academically',
#  'academy',
#  'accept',
#  'access',
#  'accessible',
#  'accessory',
#  'accommodate',
#  'accomplish',
#  'acer',
#  'achieve',
#  'achievement',
#  'acquire',
#  'act',
#  'action',
#  'active',
#  'actively',
#  'activity',
#  'actually',
#  'add',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'adhd',
#  'adjustable',
#  'adult',
#  'advance',
#  'advanced',
#  'advantage',
#  'adventure',
#  'affect',
#  'afford',
#  'african',
#  'age',
#  'ahead',
#  'aid',
#  'aim',
#  'air',
#  'alive',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'aloud',
#  'alphabet',
#  'already',
#  'also',
#  'alternative',
#  'always',
#  'amaze',
#  'amazing',
#  'amazon',
#  'amazonbasics',
#  'america',
#  'american',
#  'amount',
#  'amp',
#  'analyze',
#  'andor',
#  'animal',
#  'answer',
#  'anxiety',
#  'anymore',
#  'anything',
#  'anywhere',
#  'apart',
#  'app',
#  'apple',
#  'application',
#  'apply',
#  'appreciate',
#  'approach',
#  'appropriate',
#  'approximately',
#  'apps',
#  'area',
#  'around',
#  'arrive',
#  'art',
#  'article',
#  'artist',
#  'artistic',
#  'ask',
#  'aspect',
#  'assessment',
#  'assign',
#  'assignment',
#  'assist',
#  'assistance',
#  'assort',
#  'assorted',
#  'assortment',
#  'atmosphere',
#  'attend',
#  'attention',
#  'attitude',
#  'audio',
#  'authentic',
#  'author',
#  'autism',
#  'available',
#  'average',
#  'award',
#  'aware',
#  'awareness',
#  'away',
#  'awesome',
#  'baby',
#  'back',
#  'background',
#  'backpack',
#  'bad',
#  'bag',
#  'balance',
#  'ball',
#  'band',
#  'bar',
#  'barrier',
#  'base',
#  'basic',
#  'basis',
#  'basketball',
#  'battery',
#  'bean',
#  'beanbag',
#  'bear',
#  'beautiful',
#  'become',
#  'begin',
#  'beginner',
#  'behavior',
#  'behavioral',
#  'believe',
#  'beneficial',
#  'benefit',
#  'best',
#  'big',
#  'biggest',
#  'bilingual',
#  'bin',
#  'bit',
#  'bk',
#  'black',
#  'blend',
#  'bless',
#  'block',
#  'blue',
#  'board',
#  'body',
#  'book',
#  'boost',
#  'borrow',
#  'bottle',
#  'bounce',
#  'bouncy',
#  'box',
#  'boy',
#  'boys',
#  'brain',
#  'brand',
#  'break',
#  'breakfast',
#  'brick',
#  'bridge',
#  'bright',
#  'bring',
#  'broken',
#  'brother',
#  'brown',
#  'brush',
#  'budget',
#  'build',
#  'builder',
#  'building',
#  'bulk',
#  'bunch',
#  'bundle',
#  'burn',
#  'bus',
#  'business',
#  'busy',
#  'buy',
#  'cable',
#  'california',
#  'call',
#  'calm',
#  'camera',
#  'campus',
#  'cannot',
#  'capable',
#  'capacity',
#  'capture',
#  'car',
#  'card',
#  'care',
#  'career',
#  'carolina',
#  'carpet',
#  'carry',
#  'cart',
#  'cartridge',
#  'case',
#  'cat',
#  'catch',
#  'cause',
#  'cd',
#  'celebrate',
#  'celeron',
#  'center',
#  'central',
#  'century',
#  'certain',
#  'certainly',
#  'certify',
#  'chair',
#  'challenge',
#  'champion',
#  'chance',
#  'change',
#  'chapter',
#  'character',
#  'charge',
#  'chart',
#  'charter',
#  'check',
#  'child',
#  'childhood',
#  'childrens',
#  'chisel',
#  'choice',
#  'choose',
#  'chrome',
#  'chromebook',
#  'chromebooks',
#  'circle',
#  'circumstance',
#  'citizen',
#  'city',
#  'class',
#  'classic',
#  'classmate',
#  'classpack',
#  'classroom',
#  'clean',
#  'clear',
#  'clip',
#  'clipboard',
#  'close',
#  'club',
#  'cm',
#  'cod',
#  'code',
#  'cognitive',
#  'cold',
#  'collaborate',
#  'collaboration',
#  'collaborative',
#  'collaboratively',
#  'collect',
#  'collection',
#  'college',
#  'color',
#  'colorful',
#  'combination',
#  'combine',
#  'combo',
#  'come',
#  'comfort',
#  'comfortable',
#  'comfortably',
#  'comfy',
#  'commercial',
#  'commit',
#  'common',
#  'communicate',
#  'communication',
#  'community',
#  'compare',
#  'compatible',
#  'compete',
#  'competition',
#  'complete',
#  'completely',
#  'complex',
#  'component',
#  'comprehend',
#  'comprehension',
#  'comprise',
#  'computer',
#  'concentrate',
#  'concentration',
#  'concept',
#  'concrete',
#  'condition',
#  'conduct',
#  'confidence',
#  'confident',
#  'connect',
#  'connection',
#  'consider',
#  'consist',
#  'constant',
#  'constantly',
#  'construction',
#  'contain',
#  'content',
#  'continue',
#  'contribute',
#  'control',
#  'conversation',
#  'cool',
#  'cooperative',
#  'copy',
#  'core',
#  'corner',
#  'correct',
#  'cost',
#  'count',
#  'country',
#  'county',
#  'couple',
#  'course',
#  'cover',
#  'cozy',
#  'craft',
#  'crave',
#  'crayola',
#  'crayon',
#  'create',
#  'creation',
#  'creative',
#  'creativity',
#  'critical',
#  'critically',
#  'crucial',
#  'ct',
#  'cube',
#  'cultural',
#  'culturally',
#  'culture',
#  'cup',
#  'curiosity',
#  'curious',
#  'current',
#  'currently',
#  'curriculum',
#  'cushion',
#  'cut',
#  'cycle',
#  'daily',
#  'dance',
#  'dark',
#  'data',
#  'date',
#  'day',
#  'dd',
#  'deal',
#  'decide',
#  'decision',
#  'dedicate',
#  'deep',
#  'deeply',
#  'defender',
#  'definitely',
#  'degree',
#  'delay',
#  'deluxe',
#  'demand',
#  'demonstrate',
#  'depend',
#  'describe',
#  'deserve',
#  'design',
#  'desire',
#  'desk',
#  'desktop',
#  'detail',
#  'determine',
#  'develop',
#  'development',
#  'developmental',
#  'device',
#  'diameter',
#  'diary',
#  'dice',
#  'difference',
#  'different',
#  'differentiate',
#  'difficult',
#  'difficulty',
#  'digital',
#  'direct',
#  'direction',
#  'directly',
#  'disability',
#  'disadvantage',
#  'disc',
#  'discover',
#  'discovery',
#  'discus',
#  'discuss',
#  'discussion',
#  'disorder',
#  'display',
#  'distract',
#  'distraction',
#  'district',
#  'dive',
#  'diverse',
#  'diversity',
#  'dixon',
#  'do',
#  'document',
#  'dog',
#  'donate',
#  'donation',
#  'donor',
#  'door',
#  'dot',
#  'double',
#  'dozen',
#  'dr',
#  'draw',
#  'drawer',
#  'dream',
#  'drive',
#  'drop',
#  'dry',
#  'dryerase',
#  'dual',
#  'due',
#  'durable',
#  'duty',
#  'dynamic',
#  'eager',
#  'eagerness',
#  'early',
#  'earn',
#  'earth',
#  'ease',
#  'easel',
#  'easier',
#  'easily',
#  'easy',
#  'eat',
#  'economic',
#  'economically',
#  'economy',
#  'edge',
#  'edit',
#  'edition',
#  'educate',
#  'education',
#  'educational',
#  'educator',
#  'ee',
#  'effect',
#  'effective',
#  'effectively',
#  'effort',
#  'ela',
#  'electric',
#  'electronic',
#  'element',
#  'elementary',
#  'ell',
#  'elmers',
#  'else',
#  'embrace',
#  'emmc',
#  'emotional',
#  'empower',
#  'enable',
#  'encourage',
#  'end',
#  'endless',
#  'energetic',
#  'energy',
#  'engage',
#  'engaged',
#  'engagement',
#  'engineer',
#  'engineering',
#  'english',
#  'enhance',
#  'enjoy',
#  'enjoyable',
#  'enough',
#  'enrich',
#  'enrichment',
#  'ensure',
#  'enter',
#  'enthusiasm',
#  'enthusiastic',
#  'entire',
#  'environment',
#  'equal',
#  'equip',
#  'equipment',
#  'erase',
#  'eraser',
#  'escape',
#  'esl',
#  'especially',
#  'essential',
#  'etc',
#  'ethnic',
#  'even',
#  'event',
#  'ever',
#  'everyday',
#  'everyone',
#  'everything',
#  'exactly',
#  'example',
#  'excel',
#  'excellence',
#  'excellent',
#  'excite',
#  'excited',
#  'excitement',
#  'exciting',
#  'exercise',
#  'expand',
#  'expect',
#  'expectation',
#  'experience',
#  'experiment',
#  'explain',
#  'exploration',
#  'explore',
#  'expo',
#  'expose',
#  'exposure',
#  'express',
#  'expression',
#  'extend',
#  'extra',
#  'extreme',
#  'extremely',
#  'eye',
#  'face',
#  'facilitate',
#  'fact',
#  'factor',
#  'fairy',
#  'fall',
#  'familiar',
#  'family',
#  'fantastic',
#  'far',
#  'farm',
#  'fast',
#  'favorite',
#  'feature',
#  'feedback',
#  'feel',
#  'feeling',
#  'felt',
#  'ff',
#  'fiction',
#  'fidget',
#  'field',
#  'fifth',
#  'fight',
#  'figure',
#  'file',
#  'fill',
#  'final',
#  'finally',
#  'financial',
#  'find',
#  'fine',
#  'finger',
#  'finish',
#  'fire',
#  'first',
#  'fish',
#  'fit',
#  'fitness',
#  'flash',
#  'flat',
#  'flexibility',
#  'flexible',
#  'flip',
#  'floor',
#  'flow',
#  'fluency',
#  'fluent',
#  'fly',
#  'foam',
#  'focus',
#  'focused',
#  'fold',
#  'folder',
#  'follow',
#  'food',
#  'foot',
#  'football',
#  'force',
#  'forget',
#  'form',
#  'fortunate',
#  'forward',
#  'foster',
#  'foundation',
#  'fourth',
#  'fraction',
#  'frame',
#  'free',
#  'freedom',
#  'freereduced',
#  'frequently',
#  'fresh',
#  'friend',
#  'friendly',
#  'front',
#  'fruit',
#  'ft',
#  'full',
#  'fully',
#  'fun',
#  'function',
#  'fund',
#  'fundamental',
#  'funding',
#  'funny',
#  'furniture',
#  'future',
#  'gaiam',
#  'gain',
#  'galaxy',
#  'game',
#  'gap',
#  'garden',
#  'gather',
#  'gb',
#  'gear',
#  'general',
#  'generation',
#  'generous',
#  'genius',
#  'genre',
#  'get',
#  'gg',
#  'giant',
#  'gift',
#  'girl',
#  'give',
#  'glass',
#  'global',
#  'glue',
#  'go',
#  'goal',
#  'gold',
#  'good',
#  'google',
#  'gr',
#  'grab',
#  'grade',
#  'grader',
#  'graduate',
#  'grandparent',
#  'grant',
#  'graph',
#  'graphic',
#  'grasp',
#  'grateful',
#  'gray',
#  'great',
#  'greater',
#  'greatest',
#  'greatly',
#  'green',
#  'greet',
#  'grey',
#  'grip',
#  'group',
#  'grow',
#  'growth',
#  'guide',
#  'gym',
#  'habit',
#  'half',
#  'hand',
#  'handle',
#  'handson',
#  'hang',
#  'happen',
#  'happy',
#  'hard',
#  'hardship',
#  'hardworking',
#  'hd',
#  'head',
#  'headphone',
#  'headset',
#  'health',
#  'healthy',
#  'hear',
#  'heart',
#  'heavy',
#  'heavyduty',
#  'height',
#  'help',
#  'helpful',
#  'hero',
#  'hh',
#  'high',
#  'higher',
#  'highest',
#  'highly',
#  'highpoverty',
#  'hispanic',
#  'history',
#  'hit',
#  'hokki',
#  'hold',
#  'holder',
#  'hole',
#  'home',
#  'homeless',
#  'homework',
#  'honor',
#  'hook',
#  'hop',
#  'hope',
#  'hopeful',
#  'hopefully',
#  'hot',
#  'hour',
#  'house',
#  'household',
#  'housing',
#  'however',
#  'hp',
#  'huge',
#  'human',
#  'hundred',
#  'hungry',
#  'id',
#  'idea',
#  'ideal',
#  'identify',
#  'ii',
#  'image',
#  'imagination',
#  'imagine',
#  'immediate',
#  'immigrant',
#  'impact',
#  'impairment',
#  'implement',
#  'importance',
#  'important',
#  'importantly',
#  'improve',
#  'improvement',
#  'inch',
#  'include',
#  'inclusion',
#  'income',
#  'incorporate',
#  'increase',
#  'incredible',
#  'incredibly',
#  'independence',
#  'independent',
#  'independently',
#  'individual',
#  'individualize',
#  'individualized',
#  'individually',
#  'indoor',
#  'inflatable',
#  'information',
#  'informational',
#  'ink',
#  'inner',
#  'innovative',
#  'input',
#  'inquiry',
#  'inquisitive',
#  'insight',
#  'inspiration',
#  'inspire',
#  'instant',
#  'instead',
#  'instill',
#  'instruction',
#  'instructional',
#  'instrument',
#  'integrate',
#  'integration',
#  'intel',
#  'intellectual',
#  'intelligent',
#  'interact',
#  'interaction',
#  'interactive',
#  'interest',
#  'interested',
#  'interesting',
#  'internet',
#  'intervention',
#  'introduce',
#  'investigate',
#  'invite',
#  'involve',
#  'involved',
#  'ipad',
#  'ipads',
#  'iphone',
#  'island',
#  'issue',
#  'item',
#  'jj',
#  'job',
#  'joe',
#  'join',
#  'journal',
#  'journey',
#  'joy',
#  'jr',
#  'jumbo',
#  'jump',
#  'junior',
#  'keep',
#  'key',
#  'keyboard',
#  'kgr',
#  'kid',
#  'kiddos',
#  'kind',
#  'kindergarten',
#  'kindergartener',
#  'kindergartner',
#  'kindle',
#  'kindness',
#  'kinesthetic',
#  'kit',
#  'kitchen',
#  'know',
#  'knowledge',
#  'kore',
#  'la',
#  'lab',
#  'label',
#  'lack',
#  'lakeshore',
#  'laminate',
#  'language',
#  'languages',
#  'lap',
#  'laptop',
#  'large',
#  'larger',
#  'last',
#  'later',
#  'latest',
#  'lay',
#  'lb',
#  'lc',
#  'lead',
#  'leader',
#  'leadership',
#  'learn',
#  'learner',
#  'learning',
#  'least',
#  'leave',
#  'leg',
#  'lego',
#  'length',
#  'lenovo',
#  'less',
#  'lesson',
#  'let',
#  'letter',
#  'level',
#  'library',
#  'license',
#  'life',
#  'lifelong',
#  'lifestyle',
#  'lifetime',
#  'light',
#  'lightweight',
#  'like',
#  'likely',
#  'lime',
#  'limit',
#  'limited',
#  'line',
#  'link',
#  'liquid',
#  'list',
#  'listen',
#  'literacy',
#  'literature',
#  ...]

# %%
compute_class_weight('balanced', np.unique(y_train), y_train)
# Out:
# array([3.24545862, 0.59105947])

# %%
sample_weight = compute_sample_weight({0:3.24545862, 1:0.59105947}, y_train)

# %%
max_depth = [2,3,4,5,6,7,8,9,10]
learning_rate = np.linspace(0.0001, 2, 100)
param_grid = {'max_depth':max_depth, 'learning_rate':learning_rate}

# %%
model = xgb.XGBClassifier()

model_gs = RandomizedSearchCV(model, param_grid, cv=5, scoring='roc_auc', n_iter=10, verbose=2, n_jobs=-1)

model_gs.fit(x_train, y_train, sample_weight=sample_weight)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] max_depth=6, learning_rate=1.8989949494949496 ...................
# [CV] max_depth=6, learning_rate=1.8989949494949496 ...................
# [CV] max_depth=6, learning_rate=1.8989949494949496 ...................
# [CV] max_depth=6, learning_rate=1.8989949494949496 ...................
# [CV] .... max_depth=6, learning_rate=1.8989949494949496, total=25.3min
# [CV] max_depth=6, learning_rate=1.8989949494949496 ...................
# [CV] .... max_depth=6, learning_rate=1.8989949494949496, total=25.3min
# [CV] max_depth=4, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=6, learning_rate=1.8989949494949496, total=32.5min
# [CV] max_depth=4, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=6, learning_rate=1.8989949494949496, total=33.1min
# [CV] max_depth=4, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=4, learning_rate=1.2929646464646465, total=22.7min
# [CV] max_depth=4, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=6, learning_rate=1.8989949494949496, total=27.3min
# [CV] max_depth=4, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=4, learning_rate=1.2929646464646465, total=23.8min
# [CV] max_depth=3, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=4, learning_rate=1.2929646464646465, total=23.9min
# [CV] max_depth=3, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=4, learning_rate=1.2929646464646465, total=24.8min
# [CV] max_depth=3, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=3, learning_rate=1.2929646464646465, total=18.1min
# [CV] max_depth=3, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=3, learning_rate=1.2929646464646465, total=18.2min
# [CV] max_depth=3, learning_rate=1.2929646464646465 ...................
# [CV] .... max_depth=4, learning_rate=1.2929646464646465, total=25.5min
# [CV] max_depth=3, learning_rate=1.3535676767676768 ...................
# [CV] .... max_depth=3, learning_rate=1.2929646464646465, total=19.2min
# [CV] max_depth=3, learning_rate=1.3535676767676768 ...................
# [CV] .... max_depth=3, learning_rate=1.2929646464646465, total=19.5min
# [CV] max_depth=3, learning_rate=1.3535676767676768 ...................
# [CV] .... max_depth=3, learning_rate=1.2929646464646465, total=19.9min
# [CV] max_depth=3, learning_rate=1.3535676767676768 ...................
# [CV] .... max_depth=3, learning_rate=1.3535676767676768, total=19.8min
# [CV] max_depth=3, learning_rate=1.3535676767676768 ...................
# [CV] .... max_depth=3, learning_rate=1.3535676767676768, total=20.5min
# [CV] max_depth=9, learning_rate=1.2727636363636363 ...................
# [CV] .... max_depth=3, learning_rate=1.3535676767676768, total=20.2min
# [CV] max_depth=9, learning_rate=1.2727636363636363 ...................
# [CV] .... max_depth=3, learning_rate=1.3535676767676768, total=20.1min
# [CV] max_depth=9, learning_rate=1.2727636363636363 ...................
# [CV] .... max_depth=3, learning_rate=1.3535676767676768, total=19.2min
# [CV] max_depth=9, learning_rate=1.2727636363636363 ...................
# [CV] .... max_depth=9, learning_rate=1.2727636363636363, total=46.7min
# [CV] max_depth=9, learning_rate=1.2727636363636363 ...................
# [CV] .... max_depth=9, learning_rate=1.2727636363636363, total=47.2min
# [CV] max_depth=2, learning_rate=1.1111555555555557 ...................
# [CV] .... max_depth=9, learning_rate=1.2727636363636363, total=47.1min
# [CV] max_depth=2, learning_rate=1.1111555555555557 ...................
# [CV] .... max_depth=9, learning_rate=1.2727636363636363, total=47.0min
# [CV] max_depth=2, learning_rate=1.1111555555555557 ...................
# [CV] .... max_depth=2, learning_rate=1.1111555555555557, total=11.5min
# [CV] max_depth=2, learning_rate=1.1111555555555557 ...................
# [CV] .... max_depth=2, learning_rate=1.1111555555555557, total=11.4min
# [CV] max_depth=2, learning_rate=1.1111555555555557 ...................
# [CV] .... max_depth=2, learning_rate=1.1111555555555557, total=11.7min
# [CV] max_depth=2, learning_rate=1.8383919191919191 ...................
# [CV] .... max_depth=2, learning_rate=1.1111555555555557, total=11.4min
# [CV] max_depth=2, learning_rate=1.8383919191919191 ...................
# [CV] .... max_depth=2, learning_rate=1.1111555555555557, total=11.3min
# [CV] max_depth=2, learning_rate=1.8383919191919191 ...................
# [CV] .... max_depth=2, learning_rate=1.8383919191919191, total=11.4min
# [CV] max_depth=2, learning_rate=1.8383919191919191 ...................
# [CV] .... max_depth=2, learning_rate=1.8383919191919191, total=11.6min
# [CV] max_depth=2, learning_rate=1.8383919191919191 ...................
# [CV] .... max_depth=2, learning_rate=1.8383919191919191, total=11.4min
# [CV] max_depth=6, learning_rate=1.393969696969697 ....................
# [CV] .... max_depth=2, learning_rate=1.8383919191919191, total=11.5min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 200.4min
# [CV] max_depth=6, learning_rate=1.393969696969697 ....................
# [CV] .... max_depth=2, learning_rate=1.8383919191919191, total=11.0min
# [CV] max_depth=6, learning_rate=1.393969696969697 ....................
# [CV] .... max_depth=9, learning_rate=1.2727636363636363, total=51.7min
# [CV] max_depth=6, learning_rate=1.393969696969697 ....................
# [CV] ..... max_depth=6, learning_rate=1.393969696969697, total=33.5min
# [CV] max_depth=6, learning_rate=1.393969696969697 ....................
# [CV] ..... max_depth=6, learning_rate=1.393969696969697, total=33.5min
# [CV] max_depth=2, learning_rate=1.5555777777777777 ...................
# [CV] ..... max_depth=6, learning_rate=1.393969696969697, total=34.4min
# [CV] max_depth=2, learning_rate=1.5555777777777777 ...................
# [CV] .... max_depth=2, learning_rate=1.5555777777777777, total=11.2min
# [CV] max_depth=2, learning_rate=1.5555777777777777 ...................
# [CV] ..... max_depth=6, learning_rate=1.393969696969697, total=35.7min
# [CV] max_depth=2, learning_rate=1.5555777777777777 ...................
# [CV] .... max_depth=2, learning_rate=1.5555777777777777, total=11.9min
# [CV] max_depth=2, learning_rate=1.5555777777777777 ...................
# [CV] .... max_depth=2, learning_rate=1.5555777777777777, total=12.0min
# [CV] max_depth=10, learning_rate=0.585929292929293 ...................
# [CV] .... max_depth=2, learning_rate=1.5555777777777777, total=12.0min
# [CV] max_depth=10, learning_rate=0.585929292929293 ...................
# [CV] .... max_depth=2, learning_rate=1.5555777777777777, total=11.1min
# [CV] max_depth=10, learning_rate=0.585929292929293 ...................
# [CV] ..... max_depth=6, learning_rate=1.393969696969697, total=35.5min
# [CV] max_depth=10, learning_rate=0.585929292929293 ...................
# [CV] .... max_depth=10, learning_rate=0.585929292929293, total=52.2min
# [CV] max_depth=10, learning_rate=0.585929292929293 ...................
# [CV] .... max_depth=10, learning_rate=0.585929292929293, total=52.0min
# [CV] .... max_depth=10, learning_rate=0.585929292929293, total=50.4min
# [CV] .... max_depth=10, learning_rate=0.585929292929293, total=50.0min
# [CV] .... max_depth=10, learning_rate=0.585929292929293, total=32.9min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 342.9min finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#           fit_params=None, iid=True, n_iter=10, n_jobs=-1,
#           param_distributions={'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10], 'learning_rate': array([1.0000e-04, 2.0301e-02, ..., 1.9798e+00, 2.0000e+00])},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring='roc_auc', verbose=2)

# %%
pred = model_gs.predict(x_test)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
model_gs.score(x_test, y_test)
# Out:
# 0.7362921295681928

# %%
print(classification_report(y_test, pred,
     target_names=['rejected','approved']))
# Out:
#              precision    recall  f1-score   support
#
#    rejected       0.28      0.66      0.39      4909
#    approved       0.92      0.70      0.79     27697
#
# avg / total       0.82      0.69      0.73     32606

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[ 3243,  1666],
#        [ 8373, 19324]])

# %%
roc_auc_score(y_test, pred)
# Out:
# 0.679158117901786

# %%
test = pd.read_csv('test_clean3.csv')

# %%
test = test.rename({'proj_res_count_nostop':'proj_resouce_count_nostop'}, axis=1)

# %%
test['teacher_prefix'] = test['teacher_prefix'].astype('category')
test['school_state'] = test['school_state'].astype('category')
test['project_grade_category'] = test['project_grade_category'].astype('category')


test = pd.get_dummies(test,columns = ['teacher_prefix','school_state','project_grade_category'],drop_first=True)

# %%
list(test.columns)
# Out:
# ['id',
#  'teacher_id',
#  'project_submitted_datetime',
#  'teacher_number_of_previously_posted_projects',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'quantity_std',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'price_std',
#  'mean_price',
#  'Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'essay1_count',
#  'essay2_count',
#  'essay3_count',
#  'essay4_count',
#  'proj_res_count',
#  'desc_count',
#  'essay1_count_nostop',
#  'essay2_count_nostop',
#  'essay3_count_nostop',
#  'essay4_count_nostop',
#  'proj_resouce_count_nostop',
#  'desc_count_nostop',
#  'month',
#  'hour',
#  'minute',
#  'full_text',
#  'lemm_text',
#  'dow',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2']

# %%
count_vec_df_test = count_vec.transform(test['lemm_text'])
count_vec_df_test = pd.DataFrame(count_vec_df_test.todense(), index=test.index, columns=count_vec.get_feature_names())

# %%
scale_test = test[['teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price']]

scale_test.isna().any()
# Out:
# teacher_number_of_previously_posted_projects    False
# quantity_sum                                    False
# quantity_min                                    False
# quantity_max                                    False
# quantity_mean                                   False
# price_count                                     False
# price_sum                                       False
# price_min                                       False
# price_max                                       False
# price_mean                                      False
# mean_price                                      False
# dtype: bool

# %%
scale_features_test = scaler.transform(scale_test.values)
scale_test = pd.DataFrame(scale_features_test, index=scale_test.index, columns=scale_test.columns)

# %%
test_x = test.drop(['teacher_id','project_submitted_datetime','id','full_text','lemm_text','teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price','essay1_count',
 'essay2_count',
 'essay3_count',
 'essay4_count',
 'proj_res_count',
 'desc_count','essay1_count_nostop',
 'essay2_count_nostop',
 'essay3_count_nostop',
 'essay4_count_nostop',
 'proj_resouce_count_nostop',
 'desc_count_nostop','minute','price_std','quantity_std','hour'], 1)

# %%
pre_test_x = test_x.merge(count_vec_df_test, how='left', left_index=True, right_index=True)
full_test_x = pre_test_x.merge(scale_test, how='left', left_index=True, right_index=True)

# %%
full_test_x = full_test_x[full_x.columns].as_matrix().astype(np.float)

# %%
full_test_x.shape
# Out:
# (78035, 1816)

# %%
pred = model_gs.predict_proba(full_test_x)

# %%
pred_prob_approved = [x[1] for x in pred]

# %%
ids = np.array(test['id'])

# %%
pred_dict = {'id':ids, 'project_is_approved': pred_prob_approved}
pred_dict
# Out:
# {'id': array(['p233245', 'p096795', 'p236235', ..., 'p210728', 'p060531',
#         'p087783'], dtype=object),
#  'project_is_approved': [0.77313304,
#   0.44574988,
#   0.65006286,
#   0.8848644,
#   0.27281234,
#   0.90777254,
#   0.95108914,
#   0.77922165,
#   0.29077974,
#   0.9328222,
#   0.48341033,
#   0.54576087,
#   0.4281348,
#   0.48483998,
#   0.92703706,
#   0.83099186,
#   0.9210652,
#   0.1475335,
#   0.47157463,
#   0.2915581,
#   0.659469,
#   0.9366192,
#   0.70964557,
#   0.56021106,
#   0.37428874,
#   0.52484065,
#   0.883275,
#   0.76752234,
#   0.66190135,
#   0.8377974,
#   0.7270613,
#   0.68422306,
#   0.58109474,
#   0.75630265,
#   0.82108116,
#   0.7654137,
#   0.7393805,
#   0.55628157,
#   0.85737723,
#   0.7817702,
#   0.10296429,
#   0.7176922,
#   0.18218145,
#   0.59513724,
#   0.37063694,
#   0.46940464,
#   0.2856409,
#   0.49468768,
#   0.7072062,
#   0.44712278,
#   0.1840747,
#   0.7161427,
#   0.65908784,
#   0.9764025,
#   0.5843147,
#   0.20754002,
#   0.8625,
#   0.4189056,
#   0.90240586,
#   0.247336,
#   0.76446635,
#   0.28941235,
#   0.45668402,
#   0.30912438,
#   0.44496593,
#   0.5122396,
#   0.86389697,
#   0.34334397,
#   0.7471315,
#   0.5602692,
#   0.67626274,
#   0.7690432,
#   0.82938546,
#   0.24564268,
#   0.23948783,
#   0.47912484,
#   0.60785836,
#   0.52824134,
#   0.8192347,
#   0.8501812,
#   0.6113666,
#   0.48067653,
#   0.34096393,
#   0.45791733,
#   0.45405224,
#   0.8801109,
#   0.15063645,
#   0.07704887,
#   0.91732,
#   0.47164616,
#   0.73837686,
#   0.68273044,
#   0.72102624,
#   0.9258032,
#   0.83092594,
#   0.96870214,
#   0.74120796,
#   0.8105404,
#   0.9081382,
#   0.15084317,
#   0.78684354,
#   0.8370869,
#   0.87593883,
#   0.8484005,
#   0.82790947,
#   0.27296984,
#   0.6125381,
#   0.7084834,
#   0.23162152,
#   0.72412133,
#   0.792042,
#   0.50090677,
#   0.7719076,
#   0.18060379,
#   0.46334288,
#   0.07675416,
#   0.9814403,
#   0.25242284,
#   0.45062137,
#   0.7598619,
#   0.44349018,
#   0.8517282,
#   0.25292677,
#   0.53231287,
#   0.8824537,
#   0.14310463,
#   0.18427558,
#   0.41141003,
#   0.8625662,
