# %%
from nltk import word_tokenize
import enchant
import re
import pandas as pd

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train['full_text'] = train[['project_title','project_essay_1','project_essay_2','project_essay_3','project_essay_4','project_resource_summary']].apply(lambda x: ' '.join(x.astype(str)), axis=1)

# %%
train['full_text'] = train['full_text'].str.lower()

# %%
d = enchant.Dict("en_US")
non_dict_words = list(set([word.encode('ascii', 'ignore') for word in word_tokenize(' '.join(train['full_text'])) if d.check(word) is False and re.match('^[a-zA-Z ]*$',word)] ))
non_dict_words
# Out:
# [b'inforgraphics',
#  b'googlin',
#  b'incoroporate',
#  b'ultraportable',
#  b'baar',
#  b'genesee',
#  b'aggle',
#  b'mormon',
#  b'succcesful',
#  b'alevins',
#  b'doble',
#  b'mohandas',
#  b'milpitas',
#  b'aromatherepy',
#  b'resorces',
#  b'writeright',
#  b'strugglling',
#  b'consitstantly',
#  b'piller',
#  b'pederson',
#  b'technosavy',
#  b'unheathy',
#  b'paugh',
#  b'equitas',
#  b'condliffe',
#  b'vanda',
#  b'buildes',
#  b'rheostatic',
#  b'hbes',
#  b'prevocational',
#  b'experiance',
#  b'somthing',
#  b'clicky',
#  b'footrollers',
#  b'wonderoplois',
#  b'whizzpopping',
#  b'lavonier',
#  b'mobily',
#  b'dysregulation',
#  b'minges',
#  b'ivation',
#  b'bremen',
#  b'visionmaker',
#  b'visititing',
#  b'magnaformers',
#  b'scheving',
#  b'juicin',
#  b'applocation',
#  b'hagerstown',
#  b'fifeteen',
#  b'redhook',
#  b'dissappearing',
#  b'lern',
#  b'flemming',
#  b'zimbabwe',
#  b'nabad',
#  b'cgs',
#  b'nesecarry',
#  b'rasco',
#  b'teleoperated',
# ...

# %%
test['full_text'] = test[['project_title','project_essay_1','project_essay_2','project_essay_3','project_essay_4','project_resource_summary']].apply(lambda x: ' '.join(x.astype(str)), axis=1)

# %%
test['full_text'] = test['full_text'].str.lower()

# %%
d = enchant.Dict("en_US")
non_dict_words = list(set([word.encode('ascii', 'ignore') for word in word_tokenize(' '.join(test['full_text'])) if d.check(word) is False and re.match('^[a-zA-Z ]*$',word)] ))
non_dict_words
# Out:
# [b'northgate',
#  b'bellringer',
#  b'inforgraphics',
#  b'ucsb',
#  b'beignets',
#  b'fafsa',
#  b'oconomowoc',
#  b'accesss',
#  b'fuzzies',
#  b'bridgedale',
#  b'kokomo',
#  b'tallents',
#  b'gats',
#  b'iask',
#  b'activslate',
#  b'playdates',
#  b'genesee',
#  b'muslims',
#  b'readingeggs',
#  b'chromebox',
#  b'zzzzzzz',
#  b'cathartically',
#  b'nonmedical',
#  b'yakker',
#  b'stuggle',
#  b'philippians',
#  b'promethean',
#  b'olympus',
#  b'ppd',
#  b'coooow',
#  b'ailey',
#  b'thry',
#  b'minh',
#  b'alevins',
#  b'raburn',
#  b'merrie',
#  b'flossers',
#  b'fto',
#  b'faribault',
#  b'lacewell',
#  b'allentown',
#  b'conepts',
#  b'immidiatly',
#  b'resorces',
#  b'tanagram',
#  b'educar',
#  b'ss',
#  b'franzen',
#  b'easie',
#  b'poppeltin',
#  b'hvac',
#  b'intgrate',
#  b'justdance',
#  b'pederson',
#  b'trojan',
#  b'uhandy',
#  b'tuseday',
#  b'oballs',
#  b'stickynotes',
#  b'corretta',
#  b'calkin',
#  b'boiks',
#  b'mindplay',
#  b'casals',
#  b'excitng',
# ...
