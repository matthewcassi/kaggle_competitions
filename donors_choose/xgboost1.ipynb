# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils.class_weight import compute_sample_weight

# %%
donors_choose = pd.read_csv('train_clean3.csv')

# %%
donors_choose.head()
# Out:
#    Unnamed: 0       id                        teacher_id teacher_prefix  \
# 0           0  p036502  484aaf11257089a66cfedc9461c6bd0a            Ms.
# 1           1  p039565  df72a3ba8089423fa8a94be88060f6ed           Mrs.
# 2           2  p233823  a9b876a9252e08a55e3d894150f75ba3            Ms.
# 3           3  p185307  525fdbb6ec7f538a48beebaa0a51b24f            Mr.
# 4           4  p013780  a63b5547a7239eae4c1872670848e61a            Mr.
#
#   school_state project_submitted_datetime project_grade_category  \
# 0           NV        2016-11-18 14:45:59          Grades PreK-2
# 1           GA        2017-04-26 15:57:28             Grades 3-5
# 2           UT        2017-01-01 22:57:44             Grades 3-5
# 3           NC        2016-08-12 15:42:11             Grades 3-5
# 4           CA        2016-08-06 09:09:11             Grades 6-8
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                            26                    1
# 1                                             1                    0
# 2                                             5                    1
# 3                                            16                    0
# 4                                            42                    1
#
#    Applied Learning   ...    quantity_std  price_count  price_sum  price_min  \
# 0               0.0   ...             0.0            2     299.98     149.99
# 1               0.0   ...             NaN            1      20.00      20.00
# 2               0.0   ...             NaN            1     469.99     469.99
# 3               0.0   ...             0.0            5     684.47      18.95
# 4               0.0   ...             NaN            1     355.50     355.50
#
#    price_max  price_mean   price_std  mean_price  hour  minute
# 0     149.99     149.990    0.000000   49.996667    14      45
# 1      20.00      20.000         NaN    1.000000    15      57
# 2     469.99     469.990         NaN  469.990000    22      57
# 3     354.99     136.894  133.428098  136.894000    15      42
# 4     355.50     355.500         NaN  177.750000     9       9
#
# [5 rows x 74 columns]

# %%
donors_choose.drop('Unnamed: 0', 1, inplace=True)

# %%
donors_choose['teacher_prefix'] = donors_choose['teacher_prefix'].astype('category')
donors_choose['school_state'] = donors_choose['school_state'].astype('category')
donors_choose['project_grade_category'] = donors_choose['project_grade_category'].astype('category')
donors_choose['month'] = donors_choose['month'].astype('category')
donors_choose['dow'] = donors_choose['dow'].astype('category')

donors_choose = pd.get_dummies(donors_choose,columns = ['teacher_prefix','school_state','project_grade_category','month', 'dow'],drop_first=True)

# %%
count_vec = TfidfVectorizer(max_df=0.96, min_df=0.05, norm='l2')
count_vec_df = count_vec.fit_transform(donors_choose['lemm_text'])
count_vec_df = pd.DataFrame(count_vec_df.todense(), index=donors_choose.index, columns=count_vec.get_feature_names())

# %%
list(donors_choose.columns)
# Out:
# ['id',
#  'teacher_id',
#  'project_submitted_datetime',
#  'teacher_number_of_previously_posted_projects',
#  'project_is_approved',
#  'Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'essay1_count',
#  'essay2_count',
#  'essay3_count',
#  'essay4_count',
#  'project_resource_summary_count',
#  'desc_count',
#  'essay1_count_nostop',
#  'essay2_count_nostop',
#  'essay3_count_nostop',
#  'essay4_count_nostop',
#  'proj_resouce_count_nostop',
#  'desc_count_nostop',
#  'full_text',
#  'lemm_text',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'quantity_std',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'price_std',
#  'mean_price',
#  'hour',
#  'minute',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6']

# %%
scale_df = donors_choose[['teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price']]

scale_df.isna().any()
# Out:
# teacher_number_of_previously_posted_projects    False
# quantity_sum                                    False
# quantity_min                                    False
# quantity_max                                    False
# quantity_mean                                   False
# price_count                                     False
# price_sum                                       False
# price_min                                       False
# price_max                                       False
# price_mean                                      False
# mean_price                                      False
# dtype: bool

# %%
scaler = MinMaxScaler()
scale_features = scaler.fit_transform(scale_df.values)
scale_df= pd.DataFrame(scale_features, index=scale_df.index, columns=scale_df.columns)

# %%
x = donors_choose.drop(['teacher_id','project_submitted_datetime','project_is_approved','id','full_text','lemm_text','teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price','essay1_count',
 'essay2_count',
 'essay3_count',
 'essay4_count',
 'project_resource_summary_count',
 'desc_count','essay1_count_nostop',
 'essay2_count_nostop',
 'essay3_count_nostop',
 'essay4_count_nostop',
 'proj_resouce_count_nostop',
 'desc_count_nostop','minute','price_std','quantity_std','hour'], 1)
y = donors_choose['project_is_approved']

# %%
list(x.columns)
# Out:
# ['Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6']

# %%
pre_x = x.merge(count_vec_df, how='left', left_index=True, right_index=True)
full_x = pre_x.merge(scale_df, how='left', left_index=True, right_index=True)

full_x_array = full_x.as_matrix().astype(np.float)
y = y.as_matrix().astype(np.float)

# %%
x_train, x_test, y_train, y_test = train_test_split(full_x_array, y, test_size = 0.2, random_state=17)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((130422, 594), (32606, 594), (130422,), (32606,))

# %%
list(full_x.columns)
# Out:
# ['Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6',
#  'ability',
#  'able',
#  'academic',
#  'access',
#  'achieve',
#  'active',
#  'activity',
#  'add',
#  'addition',
#  'adult',
#  'age',
#  'allow',
#  'already',
#  'also',
#  'always',
#  'amaze',
#  'amazing',
#  'apple',
#  'area',
#  'art',
#  'ask',
#  'assort',
#  'attend',
#  'attention',
#  'available',
#  'back',
#  'background',
#  'bag',
#  'balance',
#  'ball',
#  'base',
#  'basic',
#  'basis',
#  'become',
#  'begin',
#  'believe',
#  'benefit',
#  'best',
#  'big',
#  'black',
#  'blue',
#  'board',
#  'body',
#  'book',
#  'box',
#  'brain',
#  'break',
#  'breakfast',
#  'bright',
#  'bring',
#  'build',
#  'building',
#  'cannot',
#  'card',
#  'care',
#  'career',
#  'case',
#  'celeron',
#  'center',
#  'century',
#  'chair',
#  'challenge',
#  'chance',
#  'change',
#  'child',
#  'choice',
#  'choose',
#  'chromebook',
#  'chromebooks',
#  'city',
#  'class',
#  'classic',
#  'classroom',
#  'college',
#  'color',
#  'come',
#  'comfortable',
#  'common',
#  'community',
#  'complete',
#  'comprehension',
#  'computer',
#  'concept',
#  'connect',
#  'consider',
#  'constantly',
#  'continue',
#  'core',
#  'count',
#  'cover',
#  'create',
#  'creative',
#  'creativity',
#  'critical',
#  'culture',
#  'curious',
#  'current',
#  'currently',
#  'curriculum',
#  'daily',
#  'day',
#  'deserve',
#  'design',
#  'desire',
#  'desk',
#  'develop',
#  'difference',
#  'different',
#  'difficult',
#  'digital',
#  'disability',
#  'display',
#  'district',
#  'diverse',
#  'donation',
#  'dream',
#  'due',
#  'eager',
#  'early',
#  'easy',
#  'education',
#  'educational',
#  'elementary',
#  'encourage',
#  'end',
#  'energetic',
#  'energy',
#  'engage',
#  'engagement',
#  'english',
#  'enhance',
#  'enjoy',
#  'enough',
#  'ensure',
#  'enter',
#  'environment',
#  'equipment',
#  'especially',
#  'essential',
#  'even',
#  'ever',
#  'everyday',
#  'everyone',
#  'everything',
#  'excite',
#  'excited',
#  'excitement',
#  'exercise',
#  'experience',
#  'explore',
#  'expose',
#  'extra',
#  'face',
#  'family',
#  'feel',
#  'fill',
#  'find',
#  'first',
#  'fit',
#  'flexible',
#  'floor',
#  'focus',
#  'food',
#  'forward',
#  'foster',
#  'free',
#  'full',
#  'fun',
#  'fund',
#  'future',
#  'gain',
#  'game',
#  'gb',
#  'get',
#  'give',
#  'go',
#  'goal',
#  'good',
#  'grade',
#  'grader',
#  'gray',
#  'great',
#  'greatly',
#  'green',
#  'group',
#  'grow',
#  'growth',
#  'guide',
#  'hand',
#  'handson',
#  'hard',
#  'healthy',
#  'hear',
#  'help',
#  'high',
#  'hold',
#  'home',
#  'hope',
#  'however',
#  'idea',
#  'impact',
#  'important',
#  'improve',
#  'inch',
#  'include',
#  'income',
#  'incorporate',
#  'increase',
#  'independent',
#  'individual',
#  'information',
#  'inspire',
#  'instruction',
#  'interactive',
#  'interest',
#  'ipad',
#  'ipads',
#  'issue',
#  'item',
#  'job',
#  'keep',
#  'kid',
#  'kind',
#  'kindergarten',
#  'kit',
#  'know',
#  'knowledge',
#  'lack',
#  'language',
#  'large',
#  'last',
#  'lead',
#  'learn',
#  'learner',
#  'learning',
#  'leave',
#  'lesson',
#  'let',
#  'letter',
#  'level',
#  'library',
#  'life',
#  'light',
#  'like',
#  'limit',
#  'limited',
#  'listen',
#  'literacy',
#  'little',
#  'live',
#  'locate',
#  'long',
#  'look',
#  'lot',
#  'love',
#  'low',
#  'lowincome',
#  'lunch',
#  'magnetic',
#  'majority',
#  'make',
#  'many',
#  'marker',
#  'material',
#  'math',
#  'mean',
#  'meaningful',
#  'medium',
#  'meet',
#  'memory',
#  'middle',
#  'mind',
#  'mini',
#  'minute',
#  'model',
#  'motivate',
#  'move',
#  'movement',
#  'much',
#  'multiple',
#  'music',
#  'necessary',
#  'neighborhood',
#  'never',
#  'new',
#  'next',
#  'number',
#  'offer',
#  'often',
#  'old',
#  'online',
#  'open',
#  'opportunity',
#  'option',
#  'order',
#  'organize',
#  'others',
#  'outside',
#  'pack',
#  'paper',
#  'parent',
#  'part',
#  'participate',
#  'peer',
#  'pencil',
#  'people',
#  'personal',
#  'physical',
#  'picture',
#  'piece',
#  'place',
#  'plan',
#  'plastic',
#  'play',
#  'please',
#  'point',
#  'population',
#  'positive',
#  'possible',
#  'potential',
#  'poverty',
#  'practice',
#  'prepare',
#  'print',
#  'problem',
#  'process',
#  'program',
#  'project',
#  'promote',
#  'provide',
#  'public',
#  'purchase',
#  'put',
#  'quality',
#  'question',
#  'range',
#  'reach',
#  'read',
#  'reader',
#  'reading',
#  'ready',
#  'real',
#  'really',
#  'receive',
#  'red',
#  'reduce',
#  'request',
#  'require',
#  'research',
#  'resource',
#  'right',
#  'rn',
#  'rnmy',
#  'rnrn',
#  'rnrni',
#  'rnrnmy',
#  'rnrnthe',
#  'room',
#  'run',
#  'rural',
#  'safe',
#  'say',
#  'school',
#  'science',
#  'seat',
#  'seating',
#  'second',
#  'see',
#  'sense',
#  'series',
#  'serve',
#  'set',
#  'several',
#  'share',
#  'sheet',
#  'show',
#  'single',
#  'sit',
#  'size',
#  'skill',
#  'small',
#  'smart',
#  'smile',
#  'social',
#  'socioeconomic',
#  'solve',
#  'something',
#  'sometimes',
#  'sound',
#  'space',
#  'speak',
#  'special',
#  'spend',
#  'st',
#  'stand',
#  'standard',
#  'start',
#  'state',
#  'station',
#  'stay',
#  'stem',
#  'still',
#  'stool',
#  'storage',
#  'store',
#  'story',
#  'strive',
#  'strong',
#  'struggle',
#  'study',
#  'style',
#  'subject',
#  'succeed',
#  'success',
#  'successful',
#  'supply',
#  'support',
#  'sure',
#  'system',
#  'table',
#  'tablet',
#  'take',
#  'task',
#  'teach',
#  'teacher',
#  'team',
#  'technology',
#  'tell',
#  'test',
#  'text',
#  'th',
#  'thank',
#  'thing',
#  'think',
#  'third',
#  'time',
#  'title',
#  'today',
#  'together',
#  'tool',
#  'topic',
#  'truly',
#  'try',
#  'turn',
#  'type',
#  'understand',
#  'unique',
#  'urban',
#  'use',
#  'value',
#  'variety',
#  'various',
#  'visual',
#  'vocabulary',
#  'walk',
#  'want',
#  'way',
#  'week',
#  'well',
#  'white',
#  'whole',
#  'wide',
#  'wifi',
#  'wiggle',
#  'wobble',
#  'wonderful',
#  'word',
#  'work',
#  'world',
#  'write',
#  'year',
#  'yellow',
#  'yet',
#  'young',
#  'teacher_number_of_previously_posted_projects',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'mean_price']

# %%
compute_class_weight('balanced', np.unique(y_train), y_train)
# Out:
# array([3.24545862, 0.59105947])

# %%
sample_weight = compute_sample_weight({0:3.24545862, 1:0.59105947}, y_train)

# %%
max_depth = [3,4,5,6]
learning_rate = np.linspace(0.0001, 3, 50)
param_grid = {'max_depth':max_depth, 'learning_rate':learning_rate}

# %%
model = xgb.XGBClassifier(n_jobs=-1)

model_gs = RandomizedSearchCV(model, param_grid, cv=5, scoring='roc_auc', n_iter=10, verbose=2)

model_gs.fit(x_train, y_train, sample_weight=sample_weight)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] max_depth=5, learning_rate=1.5918836734693875 ...................
# [CV] .... max_depth=5, learning_rate=1.5918836734693875, total= 6.0min
# [CV] max_depth=5, learning_rate=1.5918836734693875 ...................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  6.0min remaining:    0.0s
# [CV] .... max_depth=5, learning_rate=1.5918836734693875, total= 6.1min
# [CV] max_depth=5, learning_rate=1.5918836734693875 ...................
# [CV] .... max_depth=5, learning_rate=1.5918836734693875, total= 6.2min
# [CV] max_depth=5, learning_rate=1.5918836734693875 ...................
# [CV] .... max_depth=5, learning_rate=1.5918836734693875, total= 5.8min
# [CV] max_depth=5, learning_rate=1.5918836734693875 ...................
# [CV] .... max_depth=5, learning_rate=1.5918836734693875, total= 5.8min
# [CV] max_depth=5, learning_rate=2.0204408163265306 ...................
# [CV] .... max_depth=5, learning_rate=2.0204408163265306, total= 2.3min
# [CV] max_depth=5, learning_rate=2.0204408163265306 ...................
# [CV] .... max_depth=5, learning_rate=2.0204408163265306, total= 2.0min
# [CV] max_depth=5, learning_rate=2.0204408163265306 ...................
# [CV] .... max_depth=5, learning_rate=2.0204408163265306, total= 2.1min
# [CV] max_depth=5, learning_rate=2.0204408163265306 ...................
# [CV] .... max_depth=5, learning_rate=2.0204408163265306, total= 2.2min
# [CV] max_depth=5, learning_rate=2.0204408163265306 ...................
# [CV] .... max_depth=5, learning_rate=2.0204408163265306, total= 2.2min
# [CV] max_depth=6, learning_rate=2.8775551020408163 ...................
# [CV] .... max_depth=6, learning_rate=2.8775551020408163, total= 1.6min
# [CV] max_depth=6, learning_rate=2.8775551020408163 ...................
# [CV] .... max_depth=6, learning_rate=2.8775551020408163, total= 1.6min
# [CV] max_depth=6, learning_rate=2.8775551020408163 ...................
# [CV] .... max_depth=6, learning_rate=2.8775551020408163, total= 1.7min
# [CV] max_depth=6, learning_rate=2.8775551020408163 ...................
# [CV] .... max_depth=6, learning_rate=2.8775551020408163, total= 1.6min
# [CV] max_depth=6, learning_rate=2.8775551020408163 ...................
# [CV] .... max_depth=6, learning_rate=2.8775551020408163, total= 1.7min
# [CV] max_depth=6, learning_rate=1.1633265306122447 ...................
# [CV] .... max_depth=6, learning_rate=1.1633265306122447, total= 6.8min
# [CV] max_depth=6, learning_rate=1.1633265306122447 ...................
# [CV] .... max_depth=6, learning_rate=1.1633265306122447, total= 6.9min
# [CV] max_depth=6, learning_rate=1.1633265306122447 ...................
# [CV] .... max_depth=6, learning_rate=1.1633265306122447, total= 6.8min
# [CV] max_depth=6, learning_rate=1.1633265306122447 ...................
# [CV] .... max_depth=6, learning_rate=1.1633265306122447, total= 6.8min
# [CV] max_depth=6, learning_rate=1.1633265306122447 ...................
# [CV] .... max_depth=6, learning_rate=1.1633265306122447, total= 6.8min
# [CV] max_depth=6, learning_rate=2.0816632653061222 ...................
# [CV] .... max_depth=6, learning_rate=2.0816632653061222, total= 2.0min
# [CV] max_depth=6, learning_rate=2.0816632653061222 ...................
# [CV] .... max_depth=6, learning_rate=2.0816632653061222, total= 1.9min
# [CV] max_depth=6, learning_rate=2.0816632653061222 ...................
# [CV] .... max_depth=6, learning_rate=2.0816632653061222, total= 2.1min
# [CV] max_depth=6, learning_rate=2.0816632653061222 ...................
# [CV] .... max_depth=6, learning_rate=2.0816632653061222, total= 2.1min
# [CV] max_depth=6, learning_rate=2.0816632653061222 ...................
# [CV] .... max_depth=6, learning_rate=2.0816632653061222, total= 2.3min
# [CV] max_depth=4, learning_rate=0.12254489795918366 ..................
# [CV] ... max_depth=4, learning_rate=0.12254489795918366, total= 4.6min
# [CV] max_depth=4, learning_rate=0.12254489795918366 ..................
# [CV] ... max_depth=4, learning_rate=0.12254489795918366, total= 4.6min
# [CV] max_depth=4, learning_rate=0.12254489795918366 ..................
# [CV] ... max_depth=4, learning_rate=0.12254489795918366, total= 4.6min
# [CV] max_depth=4, learning_rate=0.12254489795918366 ..................
# [CV] ... max_depth=4, learning_rate=0.12254489795918366, total= 4.6min
# [CV] max_depth=4, learning_rate=0.12254489795918366 ..................
# [CV] ... max_depth=4, learning_rate=0.12254489795918366, total= 4.6min
# [CV] max_depth=4, learning_rate=2.265330612244898 ....................
# [CV] ..... max_depth=4, learning_rate=2.265330612244898, total= 1.6min
# [CV] max_depth=4, learning_rate=2.265330612244898 ....................
# [CV] ..... max_depth=4, learning_rate=2.265330612244898, total= 1.5min
# [CV] max_depth=4, learning_rate=2.265330612244898 ....................
# [CV] ..... max_depth=4, learning_rate=2.265330612244898, total= 1.5min
# [CV] max_depth=4, learning_rate=2.265330612244898 ....................
# [CV] ..... max_depth=4, learning_rate=2.265330612244898, total= 1.5min
# [CV] max_depth=4, learning_rate=2.265330612244898 ....................
# [CV] ..... max_depth=4, learning_rate=2.265330612244898, total= 1.5min
# [CV] max_depth=4, learning_rate=1.8979959183673467 ...................
# [CV] .... max_depth=4, learning_rate=1.8979959183673467, total= 2.2min
# [CV] max_depth=4, learning_rate=1.8979959183673467 ...................
# [CV] .... max_depth=4, learning_rate=1.8979959183673467, total= 1.8min
# [CV] max_depth=4, learning_rate=1.8979959183673467 ...................
# [CV] .... max_depth=4, learning_rate=1.8979959183673467, total= 1.7min
# [CV] max_depth=4, learning_rate=1.8979959183673467 ...................
# [CV] .... max_depth=4, learning_rate=1.8979959183673467, total= 1.9min
# [CV] max_depth=4, learning_rate=1.8979959183673467 ...................
# [CV] .... max_depth=4, learning_rate=1.8979959183673467, total= 3.3min
# [CV] max_depth=3, learning_rate=0.7347693877551019 ...................
# [CV] .... max_depth=3, learning_rate=0.7347693877551019, total= 3.6min
# [CV] max_depth=3, learning_rate=0.7347693877551019 ...................
# [CV] .... max_depth=3, learning_rate=0.7347693877551019, total= 3.7min
# [CV] max_depth=3, learning_rate=0.7347693877551019 ...................
# [CV] .... max_depth=3, learning_rate=0.7347693877551019, total= 3.6min
# [CV] max_depth=3, learning_rate=0.7347693877551019 ...................
# [CV] .... max_depth=3, learning_rate=0.7347693877551019, total= 3.6min
# [CV] max_depth=3, learning_rate=0.7347693877551019 ...................
# [CV] .... max_depth=3, learning_rate=0.7347693877551019, total= 3.6min
# [CV] max_depth=5, learning_rate=1.775551020408163 ....................
# [CV] ..... max_depth=5, learning_rate=1.775551020408163, total= 5.9min
# [CV] max_depth=5, learning_rate=1.775551020408163 ....................
# [CV] ..... max_depth=5, learning_rate=1.775551020408163, total= 5.1min
# [CV] max_depth=5, learning_rate=1.775551020408163 ....................
# [CV] ..... max_depth=5, learning_rate=1.775551020408163, total= 5.6min
# [CV] max_depth=5, learning_rate=1.775551020408163 ....................
# [CV] ..... max_depth=5, learning_rate=1.775551020408163, total= 5.7min
# [CV] max_depth=5, learning_rate=1.775551020408163 ....................
# [CV] ..... max_depth=5, learning_rate=1.775551020408163, total= 5.7min
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 182.3min finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1),
#           fit_params=None, iid=True, n_iter=10, n_jobs=1,
#           param_distributions={'max_depth': [3, 4, 5, 6], 'learning_rate': array([1.00000e-04, 6.13224e-02, 1.22545e-01, 1.83767e-01, 2.44990e-01,
#        3.06212e-01, 3.67435e-01, 4.28657e-01, 4.89880e-01, 5.51102e-01,
#        6.12324e-01, 6.73547e-01, 7.34769e-01, 7.95992e-01, 8.57214e-01,
#        9.18437e-01,... 2.63267e+00, 2.69389e+00,
#        2.75511e+00, 2.81633e+00, 2.87756e+00, 2.93878e+00, 3.00000e+00])},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring='roc_auc', verbose=2)

# %%
pred = model_gs.predict(x_test)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
model_gs.score(x_test, y_test)
# Out:
# 0.7389343031290954

# %%
print(classification_report(y_test, pred,
     target_names=['rejected','approved']))
# Out:
#              precision    recall  f1-score   support
#
#    rejected       0.28      0.67      0.39      4909
#    approved       0.92      0.69      0.79     27697
#
# avg / total       0.82      0.69      0.73     32606

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[ 3266,  1643],
#        [ 8453, 19244]])

# %%
roc_auc_score(y_test, pred)
# Out:
# 0.6800565541437033

# %%
test = pd.read_csv('test_clean3.csv')

# %%
test = test.rename({'proj_res_count_nostop':'proj_resouce_count_nostop'}, axis=1)

# %%
test['teacher_prefix'] = test['teacher_prefix'].astype('category')
test['school_state'] = test['school_state'].astype('category')
test['project_grade_category'] = test['project_grade_category'].astype('category')
test['month'] = test['month'].astype('category')
test['dow'] = test['dow'].astype('category')

test = pd.get_dummies(test,columns = ['teacher_prefix','school_state','project_grade_category','month','dow'],drop_first=True)

# %%
list(test.columns)
# Out:
# ['id',
#  'teacher_id',
#  'project_submitted_datetime',
#  'teacher_number_of_previously_posted_projects',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'quantity_std',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'price_std',
#  'mean_price',
#  'Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'essay1_count',
#  'essay2_count',
#  'essay3_count',
#  'essay4_count',
#  'proj_res_count',
#  'desc_count',
#  'essay1_count_nostop',
#  'essay2_count_nostop',
#  'essay3_count_nostop',
#  'essay4_count_nostop',
#  'proj_resouce_count_nostop',
#  'desc_count_nostop',
#  'hour',
#  'minute',
#  'full_text',
#  'lemm_text',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6']

# %%
count_vec_df_test = count_vec.transform(test['lemm_text'])
count_vec_df_test = pd.DataFrame(count_vec_df_test.todense(), index=test.index, columns=count_vec.get_feature_names())

# %%
scale_test = test[['teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price']]

scale_test.isna().any()
# Out:
# teacher_number_of_previously_posted_projects    False
# quantity_sum                                    False
# quantity_min                                    False
# quantity_max                                    False
# quantity_mean                                   False
# price_count                                     False
# price_sum                                       False
# price_min                                       False
# price_max                                       False
# price_mean                                      False
# mean_price                                      False
# dtype: bool

# %%
scale_features_test = scaler.transform(scale_test.values)
scale_test = pd.DataFrame(scale_features_test, index=scale_test.index, columns=scale_test.columns)

# %%
test_x = test.drop(['teacher_id','project_submitted_datetime','id','full_text','lemm_text','teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price','essay1_count',
 'essay2_count',
 'essay3_count',
 'essay4_count',
 'proj_res_count',
 'desc_count','essay1_count_nostop',
 'essay2_count_nostop',
 'essay3_count_nostop',
 'essay4_count_nostop',
 'proj_resouce_count_nostop',
 'desc_count_nostop','minute','price_std','quantity_std','hour'], 1)

# %%
pre_test_x = test_x.merge(count_vec_df_test, how='left', left_index=True, right_index=True)
full_test_x = pre_test_x.merge(scale_test, how='left', left_index=True, right_index=True)

# %%
full_test_x = full_test_x[full_x.columns].as_matrix().astype(np.float)

# %%
full_test_x.shape
# Out:
# (78035, 594)

# %%
pred = model_gs.predict_proba(full_test_x)

# %%
pred_prob_approved = [x[1] for x in pred]

# %%
ids = np.array(test['id'])

# %%
pred_dict = {'id':ids, 'project_is_approved': pred_prob_approved}
pred_dict
# Out:
# {'id': array(['p233245', 'p096795', 'p236235', ..., 'p210728', 'p060531',
#         'p087783'], dtype=object),
#  'project_is_approved': [0.726335,
#   0.65027463,
#   0.5923178,
#   0.6089584,
#   0.47600594,
#   0.70158917,
#   0.66081333,
#   0.71240777,
#   0.4308978,
#   0.9073456,
#   0.5282836,
#   0.65599495,
#   0.29876378,
#   0.47296995,
#   0.707054,
#   0.85986567,
#   0.8174756,
#   0.3101503,
#   0.528037,
#   0.28239688,
#   0.7123717,
#   0.8742967,
#   0.6107387,
#   0.45423388,
#   0.42631575,
#   0.5371591,
#   0.67174536,
#   0.73620003,
#   0.79624534,
#   0.6741571,
#   0.6510378,
#   0.5083904,
#   0.5462803,
#   0.720865,
#   0.81869096,
#   0.6359385,
#   0.62463385,
#   0.60562015,
#   0.579221,
#   0.55347264,
#   0.33509365,
#   0.4850194,
#   0.34292555,
#   0.63539344,
#   0.46168226,
#   0.52210045,
#   0.5553521,
#   0.52194136,
#   0.6860828,
#   0.5284089,
#   0.32430354,
#   0.5565326,
#   0.3366008,
#   0.8398182,
#   0.55182344,
#   0.26914203,
#   0.7985068,
#   0.4960216,
#   0.8243648,
#   0.38091862,
#   0.6108618,
#   0.41780964,
#   0.6536929,
#   0.43449107,
#   0.7167019,
#   0.2966506,
#   0.8015753,
#   0.5626636,
#   0.72835165,
#   0.60492444,
#   0.7149343,
#   0.78469384,
#   0.7789911,
#   0.45687088,
#   0.28915846,
#   0.42553246,
#   0.58456254,
#   0.22438923,
#   0.7847343,
#   0.6648348,
#   0.5787976,
#   0.4083877,
#   0.40314206,
#   0.53679,
#   0.52000135,
#   0.77394277,
#   0.17910083,
#   0.16264772,
#   0.75349957,
#   0.51232773,
#   0.8638852,
#   0.7950854,
#   0.80352193,
#   0.82404876,
#   0.63627446,
#   0.87265605,
#   0.70307,
#   0.8591384,
#   0.5649326,
#   0.34308845,
#   0.69463515,
#   0.6463444,
#   0.84803516,
#   0.855329,
#   0.8271178,
#   0.38492227,
#   0.73415136,
#   0.6344091,
#   0.42000702,
#   0.78375894,
#   0.7438433,
#   0.4660071,
#   0.71588963,
#   0.52205443,
#   0.4641629,
#   0.21319245,
#   0.8759822,
#   0.53630596,
#   0.4339702,
#   0.65281624,
#   0.5629093,
#   0.7848486,
#   0.32627422,
#   0.49488857,
#   0.8462681,
#   0.2920584,
#   0.39263442,
#   0.32639045,
#   0.8376523,
#   0.68202156,
#   0.7683301,
#   0.67285645,
#   0.6771157,
#   0.7931423,
#   0.35656148,
#   0.5514282,
#   0.7849939,
#   0.5329735,
#   0.38809872,
#   0.8249912,
#   0.5213063,
#   0.3935525,
#   0.6032646,
#   0.42420152,
#   0.6227707,
#   0.27797058,
#   0.42234102,
#   0.34105003,
#   0.62915623,
#   0.7178704,
#   0.7551976,
#   0.5418373,
#   0.6528739,
#   0.72288215,
#   0.3052346,
#   0.77817535,
#   0.3839459,
#   0.5326773,
#   0.6532669,
#   0.71267813,
#   0.39154392,
#   0.8428118,
#   0.58625746,
#   0.83647656,
#   0.50740117,
#   0.5270276,
#   0.63681895,
#   0.6018239,
#   0.3809068,
#   0.41261852,
#   0.5447344,
#   0.31421503,
#   0.70040834,
#   0.8141309,
#   0.7431132,
#   0.25528502,
#   0.34067097,
#   0.52680564,
#   0.6668187,
#   0.3582067,
#   0.46414462,
#   0.3442854,
#   0.45157272,
#   0.75747925,
#   0.77546114,
#   0.69198096,
#   0.62410706,
#   0.7539303,
#   0.8146719,
#   0.6479486,
#   0.6346372,
#   0.52460825,
#   0.8287871,
#   0.506114,
#   0.38520297,
#   0.7832746,
#   0.51114136,
#   0.8385772,
#   0.5944557,
#   0.695864,
#   0.577786,
#   0.51952994,
#   0.45660737,
#   0.8640074,
#   0.6047959,
#   0.6127601,
#   0.37251562,
#   0.30000496,
#   0.62737453,
#   0.61806077,
#   0.2231765,
#   0.14255841,
#   0.40970844,
#   0.4671611,
#   0.45433235,
#   0.20859948,
#   0.68397504,
#   0.61778754,
#   0.5997835,
#   0.6309744,
#   0.6863813,
#   0.6911465,
#   0.5756555,
#   0.6586001,
#   0.7769719,
#   0.45326516,
#   0.8112975,
#   0.64512837,
#   0.3444972,
#   0.6381256,
#   0.6052191,
#   0.38014942,
#   0.43153602,
#   0.6371266,
#   0.5949637,
#   0.38047192,
#   0.8410105,
#   0.31585547,
#   0.60172313,
#   0.62358385,
#   0.45970446,
#   0.7314771,
#   0.90041864,
#   0.49084926,
#   0.37381062,
#   0.30653614,
#   0.88885,
#   0.71031016,
#   0.8663295,
#   0.4417177,
#   0.7751083,
#   0.72405994,
#   0.24067324,
#   0.45385915,
#   0.7730969,
#   0.63864654,
#   0.21614066,
#   0.83569396,
#   0.4278991,
#   0.46463913,
#   0.2872709,
#   0.8392835,
#   0.61627173,
#   0.8612252,
#   0.42989075,
#   0.2039496,
#   0.58928156,
#   0.3966173,
#   0.39878035,
#   0.5050457,
#   0.6397074,
#   0.34837988,
#   0.6691206,
#   0.63070434,
#   0.42165366,
#   0.6375181,
#   0.51101226,
#   0.6189681,
#   0.68570143,
#   0.31017438,
#   0.80662376,
#   0.6565453,
#   0.7511753,
#   0.83491176,
#   0.25154456,
#   0.60372704,
#   0.5025154,
#   0.24475884,
#   0.39074683,
#   0.4297698,
#   0.21452713,
#   0.7462854,
#   0.7950477,
#   0.7424681,
#   0.58133113,
#   0.6541229,
#   0.48537883,
#   0.8824777,
#   0.7404316,
#   0.28560215,
#   0.715275,
#   0.4146486,
#   0.3373674,
#   0.74315155,
#   0.888492,
#   0.4783152,
#   0.24834813,
#   0.33516908,
#   0.45151448,
#   0.77837354,
#   0.79853755,
#   0.76131415,
#   0.6383869,
#   0.41778767,
#   0.8192979,
#   0.46005476,
#   0.50595886,
#   0.43426615,
#   0.57219404,
#   0.46300194,
#   0.2764849,
#   0.33792254,
#   0.6211669,
#   0.74044955,
#   0.67471826,
#   0.58651334,
#   0.6837945,
#   0.8065611,
#   0.6424712,
#   0.3877006,
#   0.8893623,
#   0.36477196,
#   0.3170291,
#   0.526689,
#   0.5659208,
#   0.3856498,
#   0.7324547,
#   0.62768817,
#   0.84280634,
#   0.70784706,
#   0.5971506,
#   0.4068725,
#   0.78337276,
#   0.777537,
#   0.56581295,
#   0.33205515,
#   0.6138351,
#   0.88555914,
#   0.5404953,
#   0.5445244,
#   0.5554543,
#   0.5551793,
#   0.6409983,
#   0.7848873,
#   0.60512567,
#   0.6347133,
#   0.6830482,
#   0.30386543,
#   0.62638474,
#   0.82872784,
#   0.81957567,
#   0.5561891,
#   0.31853548,
#   0.58109546,
#   0.6969136,
#   0.8671317,
#   0.5141385,
#   0.782486,
#   0.6513901,
#   0.5400501,
#   0.86367106,
#   0.7672327,
#   0.9195673,
#   0.6537729,
#   0.62357,
#   0.8209382,
#   0.603223,
#   0.68280166,
#   0.55951685,
#   0.5647181,
#   0.6535185,
#   0.4804172,
#   0.7162435,
#   0.4328515,
#   0.46388528,
#   0.30986246,
#   0.7476061,
#   0.36757746,
#   0.71556735,
#   0.57406795,
#   0.61016744,
#   0.37585068,
#   0.46373704,
#   0.5200812,
#   0.719556,
#   0.54159516,
#   0.78199416,
#   0.81731063,
#   0.6457929,
#   0.6737904,
#   0.42621827,
#   0.2959791,
#   0.7168979,
#   0.6594763,
#   0.82802397,
#   0.8079182,
#   0.688338,
#   0.6572558,
#   0.4038426,
#   0.54534984,
#   0.30528453,
#   0.75536245,
#   0.43664858,
#   0.2358831,
#   0.801542,
#   0.43750826,
#   0.62208664,
#   0.46287048,
#   0.4002827,
#   0.5444622,
#   0.55431956,
#   0.73818797,
#   0.7765993,
#   0.37511867,
#   0.6219624,
#   0.80433166,
#   0.7238657,
#   0.7651906,
#   0.7824226,
#   0.7068234,
#   0.8504017,
#   0.83396924,
#   0.4811743,
#   0.7970218,
#   0.7004363,
#   0.5477289,
#   0.41575423,
#   0.7562402,
#   0.7742114,
#   0.34257102,
#   0.44528055,
#   0.49656174,
#   0.7018805,
#   0.765322,
#   0.8363269,
#   0.26450256,
#   0.4493331,
#   0.35620925,
#   0.33279842,
#   0.6525158,
#   0.29545018,
#   0.49976945,
#   0.63263375,
#   0.29598814,
#   0.52157074,
#   0.64844596,
#   0.713329,
#   0.24796945,
#   0.59367484,
#   0.54758185,
#   0.5301673,
#   0.6584201,
#   0.30440444,
#   0.6285429,
#   0.63607335,
#   0.7506855,
#   0.7284062,
#   0.69499516,
#   0.80558467,
#   0.8324759,
#   0.80952984,
#   0.38430774,
#   0.51702654,
#   0.6085079,
#   0.69901305,
#   0.6715525,
#   0.59153676,
#   0.8084744,
#   0.50458425,
#   0.28914043,
#   0.3491928,
#   0.37064883,
#   0.64530873,
#   0.47434622,
#   0.7024649,
#   0.86272377,
#   0.48088765,
#   0.74540186,
#   0.35465357,
#   0.33285007,
#   0.74351317,
#   0.58516556,
#   0.6856227,
#   0.58373433,
#   0.3641683,
#   0.5166229,
#   0.5467245,
#   0.46106806,
#   0.5122459,
#   0.7918835,
#   0.3790368,
#   0.5289446,
#   0.5327529,
#   0.6978199,
#   0.30609536,
#   0.78371507,
#   0.548319,
#   0.5938295,
#   0.51613677,
#   0.41371775,
#   0.91777635,
#   0.76803935,
#   0.5020517,
#   0.32039833,
#   0.42056778,
#   0.49155015,
#   0.8480531,
#   0.8961834,
#   0.3098564,
#   0.2779288,
#   0.69110024,
#   0.33764517,
#   0.83959806,
#   0.6741276,
#   0.59199935,
#   0.59101725,
#   0.41500357,
#   0.43668985,
#   0.69441617,
#   0.68976474,
#   0.6742563,
#   0.5201352,
#   0.61397225,
#   0.5495035,
#   0.6905403,
#   0.7134086,
#   0.6033977,
#   0.74031246,
#   0.36061418,
#   0.76810277,
#   0.6625064,
#   0.6777749,
#   0.30025277,
#   0.3198634,
#   0.5486824,
#   0.5308107,
#   0.65741205,
#   0.55604506,
#   0.70524967,
#   0.6351638,
#   0.633314,
#   0.5205449,
#   0.7930546,
#   0.85423845,
#   0.63493097,
#   0.41808626,
#   0.42529064,
#   0.46133098,
#   0.6967082,
#   0.41887861,
#   0.21108527,
#   0.64832616,
#   0.2457513,
#   0.3613882,
#   0.7756261,
#   0.43391123,
#   0.4413264,
#   0.7075296,
#   0.7561986,
#   0.22138229,
#   0.27931792,
#   0.27208874,
#   0.4055954,
#   0.7882027,
#   0.2508058,
#   0.7888531,
#   0.24003378,
#   0.578914,
#   0.47729042,
#   0.72343254,
#   0.7920817,
#   0.69509196,
#   0.7223282,
#   0.7506363,
#   0.7790868,
#   0.44631958,
#   0.5420929,
#   0.3284762,
#   0.42308226,
#   0.8362795,
#   0.7355935,
#   0.6877247,
#   0.7430442,
#   0.61774814,
#   0.64813524,
#   0.55613726,
#   0.20709246,
#   0.2091932,
#   0.8320785,
#   0.7681547,
#   0.7447759,
#   0.43029085,
#   0.32265037,
#   0.67049617,
#   0.38726732,
#   0.69418514,
#   0.7009813,
#   0.39206886,
#   0.59083706,
#   0.6611168,
#   0.6743627,
#   0.7718979,
#   0.53244305,
#   0.75911045,
#   0.3879055,
#   0.5046274,
#   0.68228257,
#   0.7255118,
#   0.72130597,
#   0.63812417,
#   0.36318883,
#   0.80277234,
#   0.76586854,
#   0.4617391,
#   0.40448856,
#   0.6270043,
#   0.43233055,
#   0.68093634,
#   0.83958215,
#   0.42448336,
#   0.651636,
#   0.7101465,
#   0.5611537,
#   0.6625737,
#   0.52550316,
#   0.38760746,
#   0.3632044,
#   0.57543045,
#   0.2487174,
#   0.7062424,
#   0.79000825,
#   0.3927244,
#   0.61955863,
#   0.5159739,
#   0.37101185,
#   0.3132054,
#   0.5553389,
#   0.6324555,
#   0.48980156,
#   0.7535654,
#   0.7683371,
#   0.6765857,
#   0.3081157,
#   0.7805914,
#   0.36489263,
#   0.6731539,
#   0.7895489,
#   0.7358293,
#   0.4390449,
#   0.3576678,
#   0.7482452,
#   0.6918748,
#   0.573643,
#   0.5183075,
#   0.42155793,
#   0.76728123,
#   0.8029961,
#   0.60083383,
#   0.83528775,
#   0.6023974,
#   0.180028,
#   0.6656972,
#   0.31433764,
#   0.78291774,
#   0.48140007,
#   0.21314964,
#   0.3566699,
#   0.31973308,
#   0.75180435,
#   0.8440563,
#   0.37089244,
#   0.7311683,
#   0.761131,
#   0.28774238,
#   0.51165396,
#   0.65187824,
#   0.6449002,
#   0.77915967,
#   0.557615,
#   0.59203064,
#   0.52002984,
#   0.83098555,
#   0.60369074,
#   0.31685302,
#   0.786341,
#   0.7605638,
#   0.78480077,
#   0.2927138,
#   0.60413456,
#   0.32284307,
#   0.8257278,
#   0.49413002,
#   0.552634,
#   0.5313741,
#   0.7387105,
#   0.49466324,
#   0.49068892,
#   0.8528674,
#   0.57976365,
#   0.24759647,
#   0.7540209,
#   0.51155096,
#   0.6841044,
#   0.5339235,
#   0.689214,
#   0.610059,
#   0.82552135,
#   0.4439966,
#   0.37303904,
#   0.8346316,
#   0.36808774,
#   0.53835255,
#   0.3165986,
#   0.50567055,
#   0.42132553,
#   0.6617816,
#   0.86889464,
#   0.6695391,
#   0.793958,
#   0.32214034,
#   0.7526992,
#   0.3637465,
#   0.24870975,
#   0.56589544,
#   0.68554854,
#   0.756044,
#   0.6650211,
#   0.51705045,
#   0.64326555,
#   0.6236758,
#   0.7489596,
#   0.6031944,
#   0.49469432,
#   0.52354926,
#   0.6979541,
#   0.4738352,
#   0.60853565,
#   0.6702694,
#   0.29024577,
#   0.25804016,
#   0.22835454,
#   0.6386608,
#   0.72542286,
#   0.7020565,
#   0.6038136,
#   0.48693502,
#   0.4588631,
#   0.8094321,
#   0.79390204,
#   0.36652935,
#   0.4187708,
#   0.5214285,
#   0.67606986,
#   0.6050788,
#   0.4451745,
#   0.78772074,
#   0.4366304,
#   0.71267354,
#   0.19361219,
#   0.43252608,
#   0.41247594,
#   0.3548549,
#   0.67178386,
#   0.7175018,
#   0.6283509,
#   0.7111183,
#   0.36480477,
#   0.6937471,
#   0.41768366,
#   0.38368595,
#   0.5742241,
#   0.7914055,
#   0.32777402,
#   0.3146721,
#   0.8263779,
#   0.8458435,
#   0.30762222,
#   0.59717697,
#   0.2908805,
#   0.72959715,
#   0.2032962,
#   0.68721867,
#   0.4566413,
#   0.41226512,
#   0.65392727,
#   0.40884975,
#   0.46022886,
#   0.32574758,
#   0.74337316,
#   0.6538761,
#   0.51149166,
#   0.59254056,
#   0.8415845,
#   0.501168,
#   0.8549576,
#   0.7704983,
#   0.17249724,
#   0.60739744,
#   0.66543186,
#   0.46839762,
#   0.745215,
#   0.79126674,
#   0.71462494,
#   0.7118431,
#   0.30856746,
#   0.575291,
#   0.51402354,
#   0.8646412,
#   0.72686,
#   0.43455744,
#   0.7803038,
#   0.23317721,
#   0.54706913,
#   0.7450158,
#   0.8422043,
#   0.2755496,
#   0.3590192,
#   0.82329834,
#   0.5786784,
#   0.66341406,
#   0.23638394,
#   0.8333793,
#   0.33274132,
#   0.81806177,
#   0.46947813,
#   0.72709703,
#   0.30940914,
#   0.748942,
#   0.5798117,
#   0.3964282,
#   0.48789334,
#   0.28416407,
#   0.49545658,
#   0.40420213,
#   0.6011788,
#   0.56802386,
#   0.40754777,
#   0.7073068,
#   0.560996,
#   0.6454377,
#   0.6809049,
#   0.62567693,
#   0.282226,
#   0.856598,
#   0.7017094,
#   0.63480467,
#   0.6753805,
#   0.690155,
#   0.85477865,
#   0.64673,
#   0.4170837,
#   0.4790918,
#   0.3704533,
#   0.65777844,
#   0.57036936,
#   0.76638186,
#   0.17531808,
#   0.47026998,
#   0.68276876,
#   0.8458609,
#   0.64331603,
#   0.48451278,
#   0.49985602,
#   0.8154358,
#   0.3830136,
#   0.46021926,
#   0.38031948,
#   0.90232074,
#   0.6643153,
#   0.6165157,
#   0.5025531,
#   0.393058,
#   0.6068751,
#   0.66093755,
#   0.29802427,
#   0.6649102,
#   0.72697705,
#   0.77889264,
#   0.73871493,
#   0.6665463,
#   0.74128926,
#   0.5258061,
#   0.8198219,
#   0.839071,
#   0.3659414,
#   0.44825354,
#   0.32608125,
#   0.62880033,
#   0.32835847,
#   0.60776645,
#   0.6627787,
#   0.5756964,
#   0.5685893,
#   0.73715585,
#   0.28357115,
#   0.27850142,
#   0.84297705,
#   0.72282773,
#   0.75749874,
#   0.6170821,
#   0.33926982,
#   0.86608213,
#   0.34298792,
#   0.75613564,
#   0.57712924,
#   0.62708336,
#   0.4129436,
#   0.7431042,
#   0.68452257,
#   0.7901932,
#   0.61396164,
#   0.742799,
#   0.55334276,
#   0.76379865,
#   0.6622112,
#   0.4004784,
#   0.7959286,
#   0.8160619,
#   0.7495049,
#   0.6322668,
#   0.40679786,
#   0.53708863,
#   0.5092054,
#   0.5309341,
#   0.7305111,
#   0.58954114,
#   0.7049798,
#   0.7062442,
#   0.34705788,
#   0.49344102,
#   0.6319563,
#   0.8598829,
#   0.26506898,
#   0.453358,
#   0.466633,
#   0.38164544,
#   0.8331295,
#   0.8180237,
#   0.7595486,
#   0.5765579,
#   0.54630226,
#   0.46851897,
#   0.38300702,
#   0.6887784,
#   0.8834618,
#   0.68775547,
#   0.25761965,
#   0.45376006,
#   0.24603538,
#   0.34201494,
#   0.72443753,
#   0.8432927,
#   0.52653885,
#   0.4685147,
#   0.9437839,
#   0.46282354,
#   0.6800968,
#   0.53178465,
#   0.791981,
#   0.6353868,
#   0.5629792,
#   0.41750395,
#   0.44494492,
#   0.41998228,
#   0.3132472,
#   0.5458794,
#   0.8419233,
#   0.499175,
#   0.73896176,
#   0.41982234,
#   0.77519983,
#   0.2834704,
#   0.6470851,
#   0.40659872,
#   0.6659428,
#   0.87345105,
#   0.72741127,
#   0.73420846,
#   0.70973504,
#   0.399513,
#   0.29369956,
#   0.3732275,
#   0.55435395,
#   0.5923825,
#   0.5794434,
#   0.35242313,
#   0.37722924,
#   0.8224477,
#   0.2883092,
#   0.8030772,
#   ...]}

# %%
submission = pd.DataFrame(pred_dict)

# %%
submission.to_csv('xgboost1.csv', index=False)
