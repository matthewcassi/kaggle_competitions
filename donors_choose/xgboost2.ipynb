# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils.class_weight import compute_sample_weight

# %%
donors_choose = pd.read_csv('train_clean3.csv')

# %%
donors_choose.head()
# Out:
#    Unnamed: 0       id                        teacher_id teacher_prefix  \
# 0           0  p036502  484aaf11257089a66cfedc9461c6bd0a            Ms.
# 1           1  p039565  df72a3ba8089423fa8a94be88060f6ed           Mrs.
# 2           2  p233823  a9b876a9252e08a55e3d894150f75ba3            Ms.
# 3           3  p185307  525fdbb6ec7f538a48beebaa0a51b24f            Mr.
# 4           4  p013780  a63b5547a7239eae4c1872670848e61a            Mr.
#
#   school_state project_submitted_datetime project_grade_category  \
# 0           NV        2016-11-18 14:45:59          Grades PreK-2
# 1           GA        2017-04-26 15:57:28             Grades 3-5
# 2           UT        2017-01-01 22:57:44             Grades 3-5
# 3           NC        2016-08-12 15:42:11             Grades 3-5
# 4           CA        2016-08-06 09:09:11             Grades 6-8
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                            26                    1
# 1                                             1                    0
# 2                                             5                    1
# 3                                            16                    0
# 4                                            42                    1
#
#    Applied Learning   ...    quantity_std  price_count  price_sum  price_min  \
# 0               0.0   ...             0.0            2     299.98     149.99
# 1               0.0   ...             NaN            1      20.00      20.00
# 2               0.0   ...             NaN            1     469.99     469.99
# 3               0.0   ...             0.0            5     684.47      18.95
# 4               0.0   ...             NaN            1     355.50     355.50
#
#    price_max  price_mean   price_std  mean_price  hour  minute
# 0     149.99     149.990    0.000000   49.996667    14      45
# 1      20.00      20.000         NaN    1.000000    15      57
# 2     469.99     469.990         NaN  469.990000    22      57
# 3     354.99     136.894  133.428098  136.894000    15      42
# 4     355.50     355.500         NaN  177.750000     9       9
#
# [5 rows x 74 columns]

# %%
donors_choose.drop('Unnamed: 0', 1, inplace=True)

# %%
donors_choose['teacher_prefix'] = donors_choose['teacher_prefix'].astype('category')
donors_choose['school_state'] = donors_choose['school_state'].astype('category')
donors_choose['project_grade_category'] = donors_choose['project_grade_category'].astype('category')
donors_choose['month'] = donors_choose['month'].astype('category')
donors_choose['dow'] = donors_choose['dow'].astype('category')

donors_choose = pd.get_dummies(donors_choose,columns = ['teacher_prefix','school_state','project_grade_category','month', 'dow'],drop_first=True)

# %%
count_vec = TfidfVectorizer(max_df=0.97, min_df=0.05, norm='l2')
count_vec_df = count_vec.fit_transform(donors_choose['lemm_text'])
count_vec_df = pd.DataFrame(count_vec_df.todense(), index=donors_choose.index, columns=count_vec.get_feature_names())

# %%
list(donors_choose.columns)
# Out:
# ['id',
#  'teacher_id',
#  'project_submitted_datetime',
#  'teacher_number_of_previously_posted_projects',
#  'project_is_approved',
#  'Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'essay1_count',
#  'essay2_count',
#  'essay3_count',
#  'essay4_count',
#  'project_resource_summary_count',
#  'desc_count',
#  'essay1_count_nostop',
#  'essay2_count_nostop',
#  'essay3_count_nostop',
#  'essay4_count_nostop',
#  'proj_resouce_count_nostop',
#  'desc_count_nostop',
#  'full_text',
#  'lemm_text',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'quantity_std',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'price_std',
#  'mean_price',
#  'hour',
#  'minute',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6']

# %%
scale_df = donors_choose[['teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price']]

scale_df.isna().any()
# Out:
# teacher_number_of_previously_posted_projects    False
# quantity_sum                                    False
# quantity_min                                    False
# quantity_max                                    False
# quantity_mean                                   False
# price_count                                     False
# price_sum                                       False
# price_min                                       False
# price_max                                       False
# price_mean                                      False
# mean_price                                      False
# dtype: bool

# %%
scaler = MinMaxScaler()
scale_features = scaler.fit_transform(scale_df.values)
scale_df= pd.DataFrame(scale_features, index=scale_df.index, columns=scale_df.columns)

# %%
x = donors_choose.drop(['teacher_id','project_submitted_datetime','project_is_approved','id','full_text','lemm_text','teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price','essay1_count',
 'essay2_count',
 'essay3_count',
 'essay4_count',
 'project_resource_summary_count',
 'desc_count','essay1_count_nostop',
 'essay2_count_nostop',
 'essay3_count_nostop',
 'essay4_count_nostop',
 'proj_resouce_count_nostop',
 'desc_count_nostop','minute','price_std','quantity_std','hour'], 1)
y = donors_choose['project_is_approved']

# %%
list(x.columns)
# Out:
# ['Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6']

# %%
pre_x = x.merge(count_vec_df, how='left', left_index=True, right_index=True)
full_x = pre_x.merge(scale_df, how='left', left_index=True, right_index=True)

full_x_array = full_x.as_matrix().astype(np.float)
y = y.as_matrix().astype(np.float)

# %%
x_train, x_test, y_train, y_test = train_test_split(full_x_array, y, test_size = 0.2, random_state=17)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((130422, 594), (32606, 594), (130422,), (32606,))

# %%
list(full_x.columns)
# Out:
# ['Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6',
#  'ability',
#  'able',
#  'academic',
#  'access',
#  'achieve',
#  'active',
#  'activity',
#  'add',
#  'addition',
#  'adult',
#  'age',
#  'allow',
#  'already',
#  'also',
#  'always',
#  'amaze',
#  'amazing',
#  'apple',
#  'area',
#  'art',
#  'ask',
#  'assort',
#  'attend',
#  'attention',
#  'available',
#  'back',
#  'background',
#  'bag',
#  'balance',
#  'ball',
#  'base',
#  'basic',
#  'basis',
#  'become',
#  'begin',
#  'believe',
#  'benefit',
#  'best',
#  'big',
#  'black',
#  'blue',
#  'board',
#  'body',
#  'book',
#  'box',
#  'brain',
#  'break',
#  'breakfast',
#  'bright',
#  'bring',
#  'build',
#  'building',
#  'cannot',
#  'card',
#  'care',
#  'career',
#  'case',
#  'celeron',
#  'center',
#  'century',
#  'chair',
#  'challenge',
#  'chance',
#  'change',
#  'child',
#  'choice',
#  'choose',
#  'chromebook',
#  'chromebooks',
#  'city',
#  'class',
#  'classic',
#  'classroom',
#  'college',
#  'color',
#  'come',
#  'comfortable',
#  'common',
#  'community',
#  'complete',
#  'comprehension',
#  'computer',
#  'concept',
#  'connect',
#  'consider',
#  'constantly',
#  'continue',
#  'core',
#  'count',
#  'cover',
#  'create',
#  'creative',
#  'creativity',
#  'critical',
#  'culture',
#  'curious',
#  'current',
#  'currently',
#  'curriculum',
#  'daily',
#  'day',
#  'deserve',
#  'design',
#  'desire',
#  'desk',
#  'develop',
#  'difference',
#  'different',
#  'difficult',
#  'digital',
#  'disability',
#  'display',
#  'district',
#  'diverse',
#  'donation',
#  'dream',
#  'due',
#  'eager',
#  'early',
#  'easy',
#  'education',
#  'educational',
#  'elementary',
#  'encourage',
#  'end',
#  'energetic',
#  'energy',
#  'engage',
#  'engagement',
#  'english',
#  'enhance',
#  'enjoy',
#  'enough',
#  'ensure',
#  'enter',
#  'environment',
#  'equipment',
#  'especially',
#  'essential',
#  'even',
#  'ever',
#  'everyday',
#  'everyone',
#  'everything',
#  'excite',
#  'excited',
#  'excitement',
#  'exercise',
#  'experience',
#  'explore',
#  'expose',
#  'extra',
#  'face',
#  'family',
#  'feel',
#  'fill',
#  'find',
#  'first',
#  'fit',
#  'flexible',
#  'floor',
#  'focus',
#  'food',
#  'forward',
#  'foster',
#  'free',
#  'full',
#  'fun',
#  'fund',
#  'future',
#  'gain',
#  'game',
#  'gb',
#  'get',
#  'give',
#  'go',
#  'goal',
#  'good',
#  'grade',
#  'grader',
#  'gray',
#  'great',
#  'greatly',
#  'green',
#  'group',
#  'grow',
#  'growth',
#  'guide',
#  'hand',
#  'handson',
#  'hard',
#  'healthy',
#  'hear',
#  'help',
#  'high',
#  'hold',
#  'home',
#  'hope',
#  'however',
#  'idea',
#  'impact',
#  'important',
#  'improve',
#  'inch',
#  'include',
#  'income',
#  'incorporate',
#  'increase',
#  'independent',
#  'individual',
#  'information',
#  'inspire',
#  'instruction',
#  'interactive',
#  'interest',
#  'ipad',
#  'ipads',
#  'issue',
#  'item',
#  'job',
#  'keep',
#  'kid',
#  'kind',
#  'kindergarten',
#  'kit',
#  'know',
#  'knowledge',
#  'lack',
#  'language',
#  'large',
#  'last',
#  'lead',
#  'learn',
#  'learner',
#  'learning',
#  'leave',
#  'lesson',
#  'let',
#  'letter',
#  'level',
#  'library',
#  'life',
#  'light',
#  'like',
#  'limit',
#  'limited',
#  'listen',
#  'literacy',
#  'little',
#  'live',
#  'locate',
#  'long',
#  'look',
#  'lot',
#  'love',
#  'low',
#  'lowincome',
#  'lunch',
#  'magnetic',
#  'majority',
#  'make',
#  'many',
#  'marker',
#  'material',
#  'math',
#  'mean',
#  'meaningful',
#  'medium',
#  'meet',
#  'memory',
#  'middle',
#  'mind',
#  'mini',
#  'minute',
#  'model',
#  'motivate',
#  'move',
#  'movement',
#  'much',
#  'multiple',
#  'music',
#  'necessary',
#  'neighborhood',
#  'never',
#  'new',
#  'next',
#  'number',
#  'offer',
#  'often',
#  'old',
#  'online',
#  'open',
#  'opportunity',
#  'option',
#  'order',
#  'organize',
#  'others',
#  'outside',
#  'pack',
#  'paper',
#  'parent',
#  'part',
#  'participate',
#  'peer',
#  'pencil',
#  'people',
#  'personal',
#  'physical',
#  'picture',
#  'piece',
#  'place',
#  'plan',
#  'plastic',
#  'play',
#  'please',
#  'point',
#  'population',
#  'positive',
#  'possible',
#  'potential',
#  'poverty',
#  'practice',
#  'prepare',
#  'print',
#  'problem',
#  'process',
#  'program',
#  'project',
#  'promote',
#  'provide',
#  'public',
#  'purchase',
#  'put',
#  'quality',
#  'question',
#  'range',
#  'reach',
#  'read',
#  'reader',
#  'reading',
#  'ready',
#  'real',
#  'really',
#  'receive',
#  'red',
#  'reduce',
#  'request',
#  'require',
#  'research',
#  'resource',
#  'right',
#  'rn',
#  'rnmy',
#  'rnrn',
#  'rnrni',
#  'rnrnmy',
#  'rnrnthe',
#  'room',
#  'run',
#  'rural',
#  'safe',
#  'say',
#  'school',
#  'science',
#  'seat',
#  'seating',
#  'second',
#  'see',
#  'sense',
#  'series',
#  'serve',
#  'set',
#  'several',
#  'share',
#  'sheet',
#  'show',
#  'single',
#  'sit',
#  'size',
#  'skill',
#  'small',
#  'smart',
#  'smile',
#  'social',
#  'socioeconomic',
#  'solve',
#  'something',
#  'sometimes',
#  'sound',
#  'space',
#  'speak',
#  'special',
#  'spend',
#  'st',
#  'stand',
#  'standard',
#  'start',
#  'state',
#  'station',
#  'stay',
#  'stem',
#  'still',
#  'stool',
#  'storage',
#  'store',
#  'story',
#  'strive',
#  'strong',
#  'struggle',
#  'study',
#  'style',
#  'subject',
#  'succeed',
#  'success',
#  'successful',
#  'supply',
#  'support',
#  'sure',
#  'system',
#  'table',
#  'tablet',
#  'take',
#  'task',
#  'teach',
#  'teacher',
#  'team',
#  'technology',
#  'tell',
#  'test',
#  'text',
#  'th',
#  'thank',
#  'thing',
#  'think',
#  'third',
#  'time',
#  'title',
#  'today',
#  'together',
#  'tool',
#  'topic',
#  'truly',
#  'try',
#  'turn',
#  'type',
#  'understand',
#  'unique',
#  'urban',
#  'use',
#  'value',
#  'variety',
#  'various',
#  'visual',
#  'vocabulary',
#  'walk',
#  'want',
#  'way',
#  'week',
#  'well',
#  'white',
#  'whole',
#  'wide',
#  'wifi',
#  'wiggle',
#  'wobble',
#  'wonderful',
#  'word',
#  'work',
#  'world',
#  'write',
#  'year',
#  'yellow',
#  'yet',
#  'young',
#  'teacher_number_of_previously_posted_projects',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'mean_price']

# %%
compute_class_weight('balanced', np.unique(y_train), y_train)
# Out:
# array([3.24545862, 0.59105947])

# %%
sample_weight = compute_sample_weight({0:3.24545862, 1:0.59105947}, y_train)

# %%
max_depth = [2,3,4]
learning_rate = np.linspace(0.0001, 2, 50)
reg_lambda = np.linspace(0.0001, 2, 50)
param_grid = {'max_depth':max_depth, 'learning_rate':learning_rate, 'reg_lambda':reg_lambda}

# %%
model = xgb.XGBClassifier(n_jobs=2)

model_gs = RandomizedSearchCV(model, param_grid, cv=5, scoring='roc_auc', n_iter=10, verbose=2)

model_gs.fit(x_train, y_train, sample_weight=sample_weight)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429
# [CV]  reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429, total= 1.2min
# [CV] reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.2min remaining:    0.0s
# [CV]  reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429, total= 1.2min
# [CV] reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429
# [CV]  reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429, total= 1.2min
# [CV] reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429
# [CV]  reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429, total= 1.2min
# [CV] reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429
# [CV]  reg_lambda=0.40824285714285713, max_depth=2, learning_rate=1.5918571428571429, total= 1.2min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857, total= 1.3min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857, total= 1.4min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857, total= 1.3min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857, total= 1.3min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=1.836742857142857, total= 1.3min
# [CV] reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142
# [CV]  reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142, total= 2.4min
# [CV] reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142
# [CV]  reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142, total= 2.3min
# [CV] reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142
# [CV]  reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142, total= 2.2min
# [CV] reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142
# [CV]  reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142, total= 2.2min
# [CV] reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142
# [CV]  reg_lambda=0.7755714285714286, max_depth=4, learning_rate=1.6734857142857142, total= 2.2min
# [CV] reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713
# [CV]  reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713, total= 2.2min
# [CV] reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713
# [CV]  reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713, total= 2.2min
# [CV] reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713
# [CV]  reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713, total= 2.2min
# [CV] reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713
# [CV]  reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713, total= 2.2min
# [CV] reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713
# [CV]  reg_lambda=1.3469714285714285, max_depth=4, learning_rate=1.7959285714285713, total= 2.2min
# [CV] reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143
# [CV]  reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143, total= 1.1min
# [CV] reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143
# [CV]  reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143, total= 1.1min
# [CV] reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143
# [CV]  reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143, total= 1.1min
# [CV] reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143
# [CV]  reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143, total= 1.1min
# [CV] reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143
# [CV]  reg_lambda=0.20417142857142856, max_depth=2, learning_rate=0.08172857142857143, total= 1.1min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713, total= 1.1min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713, total= 1.1min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713, total= 1.1min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713, total= 1.2min
# [CV] reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713
# [CV]  reg_lambda=1.3877857142857142, max_depth=2, learning_rate=0.12254285714285713, total= 1.2min
# [CV] reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143
# [CV]  reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143, total= 1.8min
# [CV] reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143
# [CV]  reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143, total= 1.8min
# [CV] reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143
# [CV]  reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143, total= 1.8min
# [CV] reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143
# [CV]  reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143, total= 1.7min
# [CV] reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143
# [CV]  reg_lambda=0.12254285714285713, max_depth=3, learning_rate=1.1020857142857143, total= 1.7min
# [CV] reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427
# [CV]  reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427, total= 1.2min
# [CV] reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427
# [CV]  reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427, total= 2.2min
# [CV] reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427
# [CV]  reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427, total= 1.0min
# [CV] reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427
# [CV]  reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427, total= 1.0min
# [CV] reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427
# [CV]  reg_lambda=1.7959285714285713, max_depth=4, learning_rate=1.8775571428571427, total= 1.5min
# [CV] reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428
# [CV]  reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428, total= 1.8min
# [CV] reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428
# [CV]  reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428, total= 2.0min
# [CV] reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428
# [CV]  reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428, total= 1.8min
# [CV] reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428
# [CV]  reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428, total= 1.8min
# [CV] reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428
# [CV]  reg_lambda=0.3674285714285714, max_depth=3, learning_rate=1.3061571428571428, total= 1.9min
# [CV] reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143
# [CV]  reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143, total= 2.3min
# [CV] reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143
# [CV]  reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143, total= 2.5min
# [CV] reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143
# [CV]  reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143, total= 2.3min
# [CV] reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143
# [CV]  reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143, total= 2.4min
# [CV] reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143
# [CV]  reg_lambda=1.2245285714285714, max_depth=4, learning_rate=0.8163857142857143, total= 2.3min
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 84.0min finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=2, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#           fit_params=None, iid=True, n_iter=10, n_jobs=1,
#           param_distributions={'max_depth': [2, 3, 4], 'learning_rate': array([1.00000e-04, 4.09143e-02, 8.17286e-02, 1.22543e-01, 1.63357e-01,
#        2.04171e-01, 2.44986e-01, 2.85800e-01, 3.26614e-01, 3.67429e-01,
#        4.08243e-01, 4.49057e-01, 4.89871e-01, 5.30686e-01, 5.71500e-01,
#        6.12314e-01, 6.... 1.75511e+00, 1.79593e+00,
#        1.83674e+00, 1.87756e+00, 1.91837e+00, 1.95919e+00, 2.00000e+00])},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring='roc_auc', verbose=2)

# %%
pred = model_gs.predict(x_test)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
model_gs.score(x_test, y_test)
# Out:
# 0.7255478234024976

# %%
print(classification_report(y_test, pred,
     target_names=['rejected','approved']))
# Out:
#              precision    recall  f1-score   support
#
#    rejected       0.26      0.67      0.38      4909
#    approved       0.92      0.67      0.77     27697
#
# avg / total       0.82      0.67      0.71     32606

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[ 3292,  1617],
#        [ 9249, 18448]])

# %%
roc_auc_score(y_test, pred)
# Out:
# 0.6683349639909508

# %%
test = pd.read_csv('test_clean3.csv')

# %%
test = test.rename({'proj_res_count_nostop':'proj_resouce_count_nostop'}, axis=1)

# %%
test['teacher_prefix'] = test['teacher_prefix'].astype('category')
test['school_state'] = test['school_state'].astype('category')
test['project_grade_category'] = test['project_grade_category'].astype('category')
test['month'] = test['month'].astype('category')
test['dow'] = test['dow'].astype('category')

test = pd.get_dummies(test,columns = ['teacher_prefix','school_state','project_grade_category','month','dow'],drop_first=True)

# %%
list(test.columns)
# Out:
# ['id',
#  'teacher_id',
#  'project_submitted_datetime',
#  'teacher_number_of_previously_posted_projects',
#  'quantity_sum',
#  'quantity_min',
#  'quantity_max',
#  'quantity_mean',
#  'quantity_std',
#  'price_count',
#  'price_sum',
#  'price_min',
#  'price_max',
#  'price_mean',
#  'price_std',
#  'mean_price',
#  'Applied Learning',
#  'Health & Sports',
#  'History & Civics',
#  'Literacy & Language',
#  'Math & Science',
#  'Music & The Arts',
#  'Special Needs_x',
#  'Warmth Care & Hunger_x',
#  'Applied Sciences',
#  'Character Education',
#  'Civics & Government',
#  'College & Career Prep',
#  'Community Service',
#  'ESL',
#  'Early Development',
#  'Economics',
#  'Environmental Science',
#  'Extracurricular',
#  'Financial Literacy',
#  'Foreign Languages',
#  'Gym & Fitness',
#  'Health & Life Science',
#  'Health & Wellness',
#  'History & Geography',
#  'Literacy',
#  'Literature & Writing',
#  'Mathematics',
#  'Music',
#  'Nutrition Education',
#  'Other',
#  'Parent Involvement',
#  'Performing Arts',
#  'Social Sciences',
#  'Team Sports',
#  'Visual Arts',
#  'essay1_count',
#  'essay2_count',
#  'essay3_count',
#  'essay4_count',
#  'proj_res_count',
#  'desc_count',
#  'essay1_count_nostop',
#  'essay2_count_nostop',
#  'essay3_count_nostop',
#  'essay4_count_nostop',
#  'proj_resouce_count_nostop',
#  'desc_count_nostop',
#  'hour',
#  'minute',
#  'full_text',
#  'lemm_text',
#  'teacher_prefix_Mr.',
#  'teacher_prefix_Mrs.',
#  'teacher_prefix_Ms.',
#  'teacher_prefix_Teacher',
#  'school_state_AL',
#  'school_state_AR',
#  'school_state_AZ',
#  'school_state_CA',
#  'school_state_CO',
#  'school_state_CT',
#  'school_state_DC',
#  'school_state_DE',
#  'school_state_FL',
#  'school_state_GA',
#  'school_state_HI',
#  'school_state_IA',
#  'school_state_ID',
#  'school_state_IL',
#  'school_state_IN',
#  'school_state_KS',
#  'school_state_KY',
#  'school_state_LA',
#  'school_state_MA',
#  'school_state_MD',
#  'school_state_ME',
#  'school_state_MI',
#  'school_state_MN',
#  'school_state_MO',
#  'school_state_MS',
#  'school_state_MT',
#  'school_state_NC',
#  'school_state_ND',
#  'school_state_NE',
#  'school_state_NH',
#  'school_state_NJ',
#  'school_state_NM',
#  'school_state_NV',
#  'school_state_NY',
#  'school_state_OH',
#  'school_state_OK',
#  'school_state_OR',
#  'school_state_PA',
#  'school_state_RI',
#  'school_state_SC',
#  'school_state_SD',
#  'school_state_TN',
#  'school_state_TX',
#  'school_state_UT',
#  'school_state_VA',
#  'school_state_VT',
#  'school_state_WA',
#  'school_state_WI',
#  'school_state_WV',
#  'school_state_WY',
#  'project_grade_category_Grades 6-8',
#  'project_grade_category_Grades 9-12',
#  'project_grade_category_Grades PreK-2',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dow_1',
#  'dow_2',
#  'dow_3',
#  'dow_4',
#  'dow_5',
#  'dow_6']

# %%
count_vec_df_test = count_vec.transform(test['lemm_text'])
count_vec_df_test = pd.DataFrame(count_vec_df_test.todense(), index=test.index, columns=count_vec.get_feature_names())

# %%
scale_test = test[['teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price']]

scale_test.isna().any()
# Out:
# teacher_number_of_previously_posted_projects    False
# quantity_sum                                    False
# quantity_min                                    False
# quantity_max                                    False
# quantity_mean                                   False
# price_count                                     False
# price_sum                                       False
# price_min                                       False
# price_max                                       False
# price_mean                                      False
# mean_price                                      False
# dtype: bool

# %%
scale_features_test = scaler.transform(scale_test.values)
scale_test = pd.DataFrame(scale_features_test, index=scale_test.index, columns=scale_test.columns)

# %%
test_x = test.drop(['teacher_id','project_submitted_datetime','id','full_text','lemm_text','teacher_number_of_previously_posted_projects','quantity_sum',
 'quantity_min',
 'quantity_max',
 'quantity_mean',
 'price_count',
 'price_sum',
 'price_min',
 'price_max',
 'price_mean',
 'mean_price','essay1_count',
 'essay2_count',
 'essay3_count',
 'essay4_count',
 'proj_res_count',
 'desc_count','essay1_count_nostop',
 'essay2_count_nostop',
 'essay3_count_nostop',
 'essay4_count_nostop',
 'proj_resouce_count_nostop',
 'desc_count_nostop','minute','price_std','quantity_std','hour'], 1)

# %%
pre_test_x = test_x.merge(count_vec_df_test, how='left', left_index=True, right_index=True)
full_test_x = pre_test_x.merge(scale_test, how='left', left_index=True, right_index=True)

# %%
full_test_x = full_test_x[full_x.columns].as_matrix().astype(np.float)

# %%
full_test_x.shape
# Out:
# (78035, 594)

# %%
pred = model_gs.predict_proba(full_test_x)

# %%
pred_prob_approved = [x[1] for x in pred]

# %%
ids = np.array(test['id'])

# %%
pred_dict = {'id':ids, 'project_is_approved': pred_prob_approved}
pred_dict
