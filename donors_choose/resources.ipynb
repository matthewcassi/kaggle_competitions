# %%
import pandas as pd
import numpy as np
import collections
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
resources = pd.read_csv('resources.csv')

# %%
resources.head()
# Out:
#         id                                        description  quantity  \
# 0  p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1  p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2  p069063  Cory Stories: A Kid's Book About Living With Adhd         1
# 3  p069063  Dixon Ticonderoga Wood-Cased #2 HB Pencils, Bo...         2
# 4  p069063  EDUCATIONAL INSIGHTS FLUORESCENT LIGHT FILTERS...         3
#
#     price
# 0  149.00
# 1   14.95
# 2    8.45
# 3   13.59
# 4   24.95

# %%
resources['total_price'] = resources['quantity'] * resources['price']

# %%
resources.head()
# Out:
#         id                                        description  quantity  \
# 0  p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1  p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2  p069063  Cory Stories: A Kid's Book About Living With Adhd         1
# 3  p069063  Dixon Ticonderoga Wood-Cased #2 HB Pencils, Bo...         2
# 4  p069063  EDUCATIONAL INSIGHTS FLUORESCENT LIGHT FILTERS...         3
#
#     price  total_price
# 0  149.00       149.00
# 1   14.95        44.85
# 2    8.45         8.45
# 3   13.59        27.18
# 4   24.95        74.85

# %%
len(resources['description'].unique())
# Out:
# 332929

# %%
total_resources = pd.DataFrame(resources.groupby('id')['quantity','total_price'].sum())

# %%
total_resources.head()
# Out:
#          quantity  total_price
# id
# p000001         7       833.63
# p000002        21       630.28
# p000003         4       298.97
# p000004        98      1126.22
# p000005         8       702.31

# %%
max_resources = pd.DataFrame(resources.groupby('id')['quantity','total_price'].max())

# %%
max_resources.columns = ['max_quantity','max_price']
max_resources.head()
# Out:
#          max_quantity  max_price
# id
# p000001             2     522.16
# p000002             4     134.90
# p000003             1     169.00
# p000004             2     401.54
# p000005             3     323.75

# %%
min_resources = pd.DataFrame(resources.groupby('id')['quantity','total_price'].min())
min_resources.columns = ['min_quantity','min_price']
min_resources.head()
# Out:
#          min_quantity  min_price
# id
# p000001             1      47.98
# p000002             1       9.95
# p000003             1      39.99
# p000004             1       3.20
# p000005             1      54.08

# %%
total_resources['mean_price'] = total_resources['total_price'] / total_resources['quantity']

# %%
resources_more = total_resources.merge(min_resources, left_index=True, right_index=True, how='left')
resources_more = resources_more.merge(max_resources, left_index=True, right_index=True, how='left')

# %%
resources_more['id'] = resources_more.index
resources_more = resources_more.reset_index(drop=True)

# %%
resources_more.head()
# Out:
#    quantity  total_price  mean_price  min_quantity  min_price  max_quantity  \
# 0         7       833.63  119.090000             1      47.98             2
# 1        21       630.28   30.013333             1       9.95             4
# 2         4       298.97   74.742500             1      39.99             1
# 3        98      1126.22   11.492041             1       3.20             2
# 4         8       702.31   87.788750             1      54.08             3
#
#    max_price       id
# 0     522.16  p000001
# 1     134.90  p000002
# 2     169.00  p000003
# 3     401.54  p000004
# 4     323.75  p000005

# %%
resources_more[['id','quantity','total_price','min_quantity','max_quantity','min_price','max_price']].to_csv('cleaned_resources.csv', index=False)

# %%
resources_more[['id','quantity','total_price','min_quantity','max_quantity','min_price','max_price']]
# Out:
#              id  quantity  total_price  min_quantity  max_quantity  min_price  \
# 0       p000001         7       833.63             1             2      47.98
# 1       p000002        21       630.28             1             4       9.95
# 2       p000003         4       298.97             1             1      39.99
# 3       p000004        98      1126.22             1             2       3.20
# 4       p000005         8       702.31             1             3      54.08
# 5       p000006         5       130.62             1             1       2.59
# 6       p000007         6       947.88             6             6     947.88
# 7       p000008        80       296.99             1             1       2.59
# 8       p000009        45       335.40             1             2       2.45
# 9       p000010        30       332.40            30            30     332.40
# 10      p000011        20       251.80            20            20     251.80
# ...
