# %%
import pandas as pd
import numpy as np
import collections
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
resources = pd.read_csv('resources.csv')

# %%
resources.head()
# Out:
#         id                                        description  quantity  \
# 0  p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1  p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2  p069063  Cory Stories: A Kid's Book About Living With Adhd         1
# 3  p069063  Dixon Ticonderoga Wood-Cased #2 HB Pencils, Bo...         2
# 4  p069063  EDUCATIONAL INSIGHTS FLUORESCENT LIGHT FILTERS...         3
#
#     price
# 0  149.00
# 1   14.95
# 2    8.45
# 3   13.59
# 4   24.95

# %%
res = pd.DataFrame(resources[['id', 'quantity', 'price']].groupby('id').agg(\
    {'quantity': [
            'sum',
            'min', 
            'max', 
            'mean', 
            'std', 
            # lambda x: len(np.unique(x)),
        ],'price': [
            'count', 
            'sum', 
            'min', 
            'max', 
            'mean', 
            'std'
        ]}))

# %%
res.columns = ['_'.join(col) for col in res.columns]

# %%
res.rename(columns={'id_': 'id'}, inplace=True)

# %%
res['mean_price'] = res['price_sum']/res['quantity_sum']

# %%
res.head()
# Out:
#          quantity_sum  quantity_min  quantity_max  quantity_mean  \
# id
# p000001             7             1             2       1.750000
# p000002            21             1             4       1.500000
# p000003             4             1             1       1.000000
# p000004            98             1             2       1.031579
# p000005             8             1             3       2.000000
#
#          quantity_std  price_count  price_sum  price_min  price_max  \
# id
# p000001      0.500000            4     459.56      23.99     261.08
# p000002      0.854850           14     515.89       8.46     134.90
# p000003      0.000000            4     298.97      39.99     169.00
# p000004      0.175804           95    1113.69       1.60     401.54
# p000005      1.154701            4     485.99      54.08     323.75
#
#          price_mean   price_std  mean_price
# id
# p000001  114.890000  101.929679   65.651429
# p000002   36.849286   33.549557   24.566190
# ...

# %%
res.isna().any()
# Out:
# quantity_sum     False
# quantity_min     False
# quantity_max     False
# quantity_mean    False
# quantity_std      True
# price_count      False
# price_sum        False
# price_min        False
# price_max        False
# price_mean       False
# price_std         True
# mean_price       False
# dtype: bool

# %%
desc = pd.DataFrame(resources.groupby('id')['description'].agg(lambda col: ' '.join(col.astype(str))))

# %%
desc
# Out:
#                                                description
# id
# p000001  Cap Barbell 300 Pound Olympic Set, Grey Cap Ba...
# p000002  10 Sony Headphones (BUY 9 GET 1 FREE) Belkin 6...
# p000003  EE820X - Phonemic Awareness Instant Learning C...
# p000004  A Bad Case of the Giggles Poems That Will Make...
# p000005  Fitbit Zip Wireless Activity Tracker, Lime Fit...
# p000006  Danny and the Dinosaur: 50th Anniversary Editi...
# p000007  HP Chromebook 11 G4 11.6 Inch Laptop (Intel N2...
# p000008  A Whale of a Tale Alvin and the Chipmunks Alvi...
# p000009  Ball Don't Lie Baseball Card Adventure (4 Bk S...
# p000010  Easy Spanish Reader Premium, Third Edition: A ...
# p000011            Dixon Ticonderoga Pencils, No. 2, 96/Pk
# p000012  Big Joe Cube /w Ottoman in Smartmax, Black Qua...
# p000013  Balance Buddy Bolster Swing For OntheGo 3 Swin...
# p000014               Classic Royal Reading Writing Center
# p000015             Apple - iPad Air 2 Wi-Fi 32GB - Silver
# ...

# %%
desc['description'] = desc['description'].str.lower()

# %%
desc['description'] = desc['description'].str.replace(r'(?<![a-z])don\'t(?![a-z])', 'do not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])haven\'t(?![a-z])', 'have not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])i\'m(?![a-z])', 'i am', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])i\'ll(?![a-z])', 'i will', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])i\'ve(?![a-z])', 'i have', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])can\'t(?![a-z])', 'can not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])you\'re(?![a-z])', 'you are', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])isn\'t(?![a-z])', 'is not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])you\'ll(?![a-z])', 'you will', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])you\'ve(?![a-z])', 'you have', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])he\'s(?![a-z])', 'he is', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])he\'ll(?![a-z])', 'he will', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])she\'s(?![a-z])', 'she is', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])it\'s(?![a-z])', 'it is', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])it\'ll(?![a-z])', 'it will', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])we\'re(?![a-z])', 'we are', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])we\'ll(?![a-z])', 'we will', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])they\'re(?![a-z])', 'they are', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])that\'s(?![a-z])', 'that is', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])wasn\'t(?![a-z])', 'was not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])weren\'t(?![a-z])', 'were not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])aren\'t(?![a-z])', 'are not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])hasn\'t(?![a-z])', 'has not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])hadn\'t(?![a-z])', 'had not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])won\'t(?![a-z])', 'will not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])wouldn\'t(?![a-z])', 'would', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])don\'t(?![a-z])', 'do not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])doesn\'t(?![a-z])', 'does not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])didn\'t(?![a-z])', 'did not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])couldn\'t(?![a-z])', 'could not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])shouldn\'t(?![a-z])', 'should not', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])inforgraphics(?![a-z])', 'information graphics', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])googlin(?![a-z])', 'googling', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])incoroporate(?![a-z])', 'incorporate', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])ultraportable(?![a-z])', 'ultra portable', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])succcesful(?![a-z])', 'successful', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])doble(?![a-z])', 'double', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])aromatherepy(?![a-z])', 'aromatherapy', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])resorces(?![a-z])', 'resources', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])strugglling(?![a-z])', 'struggling', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])consitstantly(?![a-z])', 'consistantly', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])piller(?![a-z])', 'pillar', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])technosavy(?![a-z])', 'tech-savy', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])unheathy(?![a-z])', 'unhealthy', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])experiance(?![a-z])', 'experience', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])somthing(?![a-z])', 'something', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])wonderoplois(?![a-z])', 'wonderopolis', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])visionmaker(?![a-z])', 'vision maker', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])visititing(?![a-z])', 'visiting', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])magnaformers(?![a-z])', 'magformers', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])scheving(?![a-z])', 'skeeving', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])juicin(?![a-z])', 'juicing', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])applocation(?![a-z])', 'application', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])fifeteen(?![a-z])', 'fifteen', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])dissappearing(?![a-z])', 'disappearing', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])lern(?![a-z])', 'learn', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])nesecarry(?![a-z])', 'necessary', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])instructuion(?![a-z])', 'instruction', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])famlies(?![a-z])', 'families', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])flipcamera(?![a-z])', 'flip camera', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])geaux(?![a-z])', 'go', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])fullly(?![a-z])', 'fully', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])fitbrain(?![a-z])', 'fit brain', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])gameup(?![a-z])', 'game up', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])typcially(?![a-z])', 'typically', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])helprobably(?![a-z])', 'he probably', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])chillout(?![a-z])', 'chill out', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])scientits(?![a-z])', 'scientists', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])subsistance(?![a-z])', 'subsistence', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])attaaack(?![a-z])', 'attack', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])healthysnacks(?![a-z])', 'healthy snacks', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])assessements(?![a-z])', 'assessments', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])allegeries(?![a-z])', 'allergies', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])dyanmath(?![a-z])', 'dynamath', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])spiltters(?![a-z])', 'splitters', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])surronded(?![a-z])', 'surrounded', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])utilitze(?![a-z])', 'utilize', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])nregular(?![a-z])', 'regular', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])readinglanugage(?![a-z])', 'reading language', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])acadamy(?![a-z])', 'academy', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])resortativr(?![a-z])', 'restorative', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])emphasising(?![a-z])', 'emphasizing', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])ctivity(?![a-z])', 'activity', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])hygeine(?![a-z])', 'hygiene', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])meterstick(?![a-z])', 'meter stick', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])expourse(?![a-z])', 'exposure', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])approachs(?![a-z])', 'approaches', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])andtwo(?![a-z])', 'and two', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])fitibits(?![a-z])', 'fit bits', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])thesee(?![a-z])', 'these', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])pesonally(?![a-z])', 'personally', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])efective(?![a-z])', 'effective', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])durring(?![a-z])', 'during', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])sdljlkjasdf(?![a-z])', '', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])indesdructable(?![a-z])', 'indestructable', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])responisble(?![a-z])', 'responsible', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])teammwork(?![a-z])', 'teamwork', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])mathmetician(?![a-z])', 'mathematician', case=False)
desc['description'] = desc['description'].str.replace(r'(?<![a-z])ofachild(?![a-z])', 'of a child', case=False)

# %%
desc['description'] = desc['description'].str.replace(r'[^a-zA-Z ]+', '')

# %%
desc.head()
# Out:
#                                                description
# id
# p000001  cap barbell  pound olympic set grey cap barbel...
# p000002   sony headphones buy  get  free belkin outlet ...
# p000003  eex  phonemic awareness instant learning cente...
# p000004  a bad case of the giggles poems that will make...
# p000005  fitbit zip wireless activity tracker lime fitb...

# %%
res = res.merge(desc, how='left', left_index=True, right_index=True)

# %%
res.head()
# Out:
#          quantity_sum  quantity_min  quantity_max  quantity_mean  \
# id
# p000001             7             1             2       1.750000
# p000002            21             1             4       1.500000
# p000003             4             1             1       1.000000
# p000004            98             1             2       1.031579
# p000005             8             1             3       2.000000
#
#          quantity_std  price_count  price_sum  price_min  price_max  \
# id
# p000001      0.500000            4     459.56      23.99     261.08
# p000002      0.854850           14     515.89       8.46     134.90
# p000003      0.000000            4     298.97      39.99     169.00
# p000004      0.175804           95    1113.69       1.60     401.54
# p000005      1.154701            4     485.99      54.08     323.75
#
#          price_mean   price_std  mean_price  \
# id
# p000001  114.890000  101.929679   65.651429
# p000002   36.849286   33.549557   24.566190
# ...

# %%
res.to_csv('cleaned_resources.csv')
